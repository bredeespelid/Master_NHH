# %% [markdown]
# #Set up the API

# %%
# Installing the required packages
# %pip install -U openai pydantic
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.52.2)
# Collecting openai
#   Downloading openai-1.54.3-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (2.9.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.6.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.6)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic) (2.23.4)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Downloading openai-1.54.3-py3-none-any.whl (389 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 389.6/389.6 kB 6.3 MB/s eta 0:00:00
# Installing collected packages: openai
#   Attempting uninstall: openai
#     Found existing installation: openai 1.52.2
#     Uninstalling openai-1.52.2:
#       Successfully uninstalled openai-1.52.2
# Successfully installed openai-1.54.3

# %%
# Set environment variables and create openai client

import os
from openai import AzureOpenAI
from google.colab import userdata # To get the secret keys

# Deployment name in azure openai studio
gpt_model = "gpt-4o-mini"  # ex. gpt-4o-mini

client = AzureOpenAI(
    api_key=userdata.get('AZURE_OPENAI_API_KEY'),
    api_version="2023-03-15-preview",
    azure_endpoint=userdata.get('AZURE_OPENAI_ENDPOINT'),
)

# %%
# Test that everything is working
messages = [{"role": "user", "content": "Hello, ready for some AI analysis?"}]
response = client.chat.completions.create(model=gpt_model, messages=messages, max_tokens=50)

print("Response: \n", response.choices[0].message.content)

# Expected respnse should be something like:
# Response:
#  Absolutely! What do you need analyzed?
# Out:
# Response:
#  Hello! Absolutely, I'm ready for some AI analysis. What topic or area would you like to explore?

# %%
# !pip install yt-dlp

import yt_dlp
import os

##---------------------------------------Test for subtitles download**


def main():
    url = "https://tv.nrk.no/serie/debatten/sesong/202410/episode/NNFA51101024"

    download_path = os.path.join(os.getcwd(), "Debatten_subtitles")
    os.makedirs(download_path, exist_ok=True)

    ydl_opts = {
        'writesubtitles': True,
        'subtitleslangs': ['nb-ttv'],  # Norsk bokmål TV-teksting
        'skip_download': True,  # Hopp over nedlasting av video
        'outtmpl': os.path.join(download_path, '%(title)s.%(ext)s'),
        'quiet': False,
        'no_warnings': True,
        'postprocessors': [{
            'key': 'FFmpegSubtitlesConvertor',
            'format': 'srt',
        }],
    }

    try:
        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            ydl.download([url])
        print(f"Subtitles downloaded to -> : {download_path}")
    except Exception as e:
        print(f"En feil oppstod: {e}")

if __name__ == "__main__":
    main()
# Out:
# Collecting yt-dlp
#   Using cached yt_dlp-2024.11.4-py3-none-any.whl.metadata (172 kB)
# Downloading yt_dlp-2024.11.4-py3-none-any.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 24.5 MB/s eta 0:00:00
# Installing collected packages: yt-dlp
# Successfully installed yt-dlp-2024.11.4
# [NRKTV] Extracting URL: https://tv.nrk.no/serie/debatten/sesong/202410/episode/NNFA51101024
# [NRK] Extracting URL: nrk:NNFA51101024
# [NRK] NNFA51101024: Downloading manifest JSON
# [NRK] NNFA51101024: Downloading m3u8 information
# [NRK] NNFA51101024: Downloading metadata JSON
# [NRK] NNFA51101024: Downloading programs JSON
# [info] NNFA51101024: Downloading subtitles: nb-ttv
# [info] NNFA51101024: Downloading 1 format(s): 2350+aud2-Unknown
# [info] Writing video subtitles to: /content/Debatten_subtitles/Debatten - 10. okt. · Bløffebudsjett, mener opposisjonen.nb-ttv.vtt
# [download] Destination: /content/Debatten_subtitles/Debatten - 10. okt. · Bløffebudsjett, mener opposisjonen.nb-ttv.vtt
# [download] 100% of   63.29KiB in 00:00:00 at 87.56KiB/s
# Subtitles downloaded to -> : /content/Debatten_subtitles

# %% [markdown]
# #Food-debate

# %%
import json
from openai.types.chat import ChatCompletionUserMessageParam, ChatCompletionSystemMessageParam

path_to_file = "Test.txt"

# Read the data from the file
with open(path_to_file, "r", encoding="UTF-8") as file:
    data = file.read()

messages = [
    ChatCompletionSystemMessageParam(
        role="system",
        content="""
            You are an expert in language analysis and interaction analysis in discussions, with a focus on identifying all unique speakers in dialogue.
Your task is to analyze the entire text provided and:

1. Identify and label each unique speaker based on their speech patterns, contextual cues, or dialogue markers.
2. Assign a unique identifier to each speaker (e.g., "Speaker 1," "Speaker 2," etc.) and determine their gender (M/F) when possible based on context.
3. Include all participants present in the text and ensure no speaker is omitted. Do not limit the identification to a predefined number of examples.
4. Look for shifts in tone, specific language usage, or structural cues in the dialogue to differentiate speakers.
3. Examine Interaction Styles:
            - Detailed Tone Categorization: Break down the tone analysis into subcategories, such as empathetic, argumentative, defensive, or conciliatory, to gain a more comprehensive understanding of the interaction style.
            - Emotion Detection: Incorporate sentiment analysis tools to detect emotions like frustration, enthusiasm, or sarcasm. This helps capture subtle nuances in interactions that extend beyond simple supportive or critical categories.
            - Power Dynamics: Analyze indications of power imbalances, such as frequent interruptions, speaking over others, or dismissive responses.
4. Use an analysis model: Analyze how gender patterns may influence treatment in interactions, while controlling for other variables.

Analyze the interactions between all participants and categorize them into gender-based combinations (M to M, F to M, F to F, M to F). Ensure the output is presented in JSON format as follows:
{
    "episode_name": "<generated_name>",
    "participants": [
        {
            "role": "<role>",
            "gender": "<M/F>",
            "background": "(party affiliation, organization, etc.)"
        }
    ],
    "interaction_analysis": {
        "M_to_M": {
            "summary": "<summary>",
            "score": <number>
        },
        "F_to_F": {
            "summary": "<summary>",
            "score": <number>
        },
        "F_to_M": {
            "summary": "<summary>",
            "score": <number>
        },
        "M_to_F": {
            "summary": "<summary>",
            "score": <number>
        }
    },
    "overall_trends": "<description>",
    "final_score": <number>
}
""",
    ),
    ChatCompletionUserMessageParam(
        role="user",
        content=f"""
            Analyze the text below and categorize participants as “debater 1,” “debater 2,” “expert 1,” etc.
            Evaluate how they interact with each other in all gender combinations (M to M, F to M, F to F, M to F).
            Include all participants and do not include the moderator in the analysis.
            In English only.

            <data>{data}</data>

        Response:
        """,
    ),
]

completion = client.chat.completions.create(
    model="gpt-4o-mini",  # Replace with your actual model name
    messages=messages,
    temperature=0,
    response_format={"type": "json_object"},  # Guarantees that the response is in JSON format
)

assert completion.choices[0].message.content is not None

# Print and parse the JSON response
print(completion.choices[0].message.content)

analysis_result = json.loads(completion.choices[0].message.content)
print("Overall score for analysis:", analysis_result["final_score"])

# %% [markdown]
# #Political Debate

# %%
import json
from openai.types.chat import ChatCompletionUserMessageParam, ChatCompletionSystemMessageParam

path_to_file = "/content/Debatten_subtitles/Test.vtt"

# Read the data from the file
with open(path_to_file, "r", encoding="UTF-8") as file:
    data = file.read()

messages = [
    ChatCompletionSystemMessageParam(
        role="system",
        content="""
            You are an expert in language analysis and interaction analysis in discussions, with a focus on identifying all unique speakers in dialogue.
Your task is to analyze the entire text provided and:

1. Identify and label each unique speaker based on their speech patterns, contextual cues, or dialogue markers.
2. Assign a unique identifier to each speaker (e.g., "Speaker 1," "Speaker 2," etc.) and determine their gender (M/F) when possible based on context.
3. Include all participants present in the text and ensure no speaker is omitted. Do not limit the identification to a predefined number of examples.
4. Look for shifts in tone, specific language usage, or structural cues in the dialogue to differentiate speakers.
5. Comprehensive Interaction Analysis: Evaluate and score the interactions between all debaters, not just a sample. This analysis should include every interaction and response in the provided text to ensure an accurate and holistic assessment of how each participant interacts with others.
  Scoring Categories:
    -Argument Strength: Rate the clarity, relevance, and persuasiveness of each participant’s arguments throughout the discussion.
    -Engagement Style: Assess interaction qualities such as empathy, assertiveness, defensiveness, or conciliation as demonstrated across all dialogue.
    -Tone Dynamics: Identify variations in tone such as supportive, critical, sarcastic, or enthusiastic exchanges, considering the entire range of interactions.
    -Power Dynamics: Score power displays or imbalances, such as interruptions, speaking over others, or dismissive responses, over the entire debate.
6. Use an analysis model: Analyze how gender patterns may influence treatment in interactions, while controlling for other variables.
7. Scoring: All scoring should be in the interval 1-10, 1 is the lowest and 10 is the highest.
8. Final Scoring: Combine scores across all categories for each participant to assign a final score reflecting their overall performance and engagement style in the full debate.

Analyze the interactions between all participants and categorize them into gender-based combinations (M to M, F to M, F to F, M to F). Ensure the output is presented in JSON format as follows:
{
    "episode_name": "<generated_name>",
    "participants": [
        {
            "role": "<role>",
            "gender": "<M/F>",
            "background": "(party affiliation, organization, etc.)"
        }
    ],
                        "interaction_analysis": {
                            "M_to_M": {
                                "Argument Strenght": <number>,
                                "Summary Argument Strenght": <summary>,
                                "Engagement Style": <number>,
                                "Summary Engagement style": <summary>,
                                "Tone Dynamics": <number>,
                                "Summary Tone Dynamics": <summary>,
                                "Power Dynamics": <number>,
                                "Summary Power Dynamics": <summary>,
                                "Total score (average of all)": <number>,
                                "Total summary": "<summary>"

                            },
                            "F_to_F": {
                                "Argument Strenght": <number>,
                                "Summary Argument Strenght": <summary>,
                                "Engagement Style": <number>,
                                "Summary Engagement style": <summary>,
                                "Tone Dynamics": <number>,
                                "Summary Tone Dynamics": <summary>,
                                "Power Dynamics": <number>,
                                "Summary Power Dynamics": <summary>,
                                "Total score (average of all)": <number>,
                                "Total summary": "<summary>"
                            },
                            "F_to_M": {
                                "Argument Strenght": <number>,
                                "Summary Argument Strenght": <summary>,
                                "Engagement Style": <number>,
                                "Summary Engagement style": <summary>,
                                "Tone Dynamics": <number>,
                                "Summary Tone Dynamics": <summary>,
                                "Power Dynamics": <number>,
                                "Summary Power Dynamics": <summary>,
                                "Total score (average of all)": <number>,
                                "Total summary": "<summary>"
                            },
                            "M_to_F": {
                                "Argument Strenght": <number>,
                                "Summary Argument Strenght": <summary>,
                                "Engagement Style": <number>,
                                "Summary Engagement style": <summary>,
                                "Tone Dynamics": <number>,
                                "Summary Tone Dynamics": <summary>,
                                "Power Dynamics": <number>,
                                "Summary Power Dynamics": <summary>,
                                "Total score (average of all)": <number>,
                                "Total summary": "<summary>"
                            }
                        },
                        "overall_trends": "<description>",
                        "final_score": <number>
                            }
""",
    ),
    ChatCompletionUserMessageParam(
        role="user",
        content=f"""
            Analyze the text below and categorize participants as “debater 1,” “debater 2,” “expert 1,” etc not their real name.
            Evaluate how they interact with each other in all gender combinations (M to M, F to M, F to F, M to F).
            Include all participants and do not include the moderator in the analysis.
            In English only.

            <data>{data}</data>

        Response:
        """,
    ),
]

completion = client.chat.completions.create(
    model="gpt-4o-mini",  # Replace with your actual model name
    messages=messages,
    temperature=0.5,
    response_format={"type": "json_object"},  # Guarantees that the response is in JSON format
)

assert completion.choices[0].message.content is not None

# Print and parse the JSON response
print(completion.choices[0].message.content)

analysis_result = json.loads(completion.choices[0].message.content)
print("Overall score for analysis:", analysis_result["final_score"])
# Out:
# {
#     "episode_name": "Norwegian Political Debate Analysis",
#     "participants": [
#         {
#             "role": "Debater 1",
#             "gender": "M",
#             "background": "Leader of the Labour Party (Ap)"
#         },
#         {
#             "role": "Debater 2",
#             "gender": "F",
#             "background": "Leader of the Conservative Party (Høyre)"
#         },
#         {
#             "role": "Debater 3",
#             "gender": "M",
#             "background": "Leader of the Progress Party (Frp)"
#         },
#         {
#             "role": "Debater 4",
#             "gender": "F",
#             "background": "Leader of the Socialist Left Party (SV)"
#         },
#         {
#             "role": "Debater 5",
#             "gender": "F",
#             "background": "Leader of the Centre Party (Sp)"
#         },
#         {
#             "role": "Debater 6",
#             "gender": "F",
#             "background": "Leader of the Red Party (Rødt)"
#         },
#         {
#             "role": "Debater 7",
#             "gender": "F",
#             "background": "Leader of the Christian Democratic Party (KrF)"
#         }
#     ],
#     "interaction_analysis": {
#         "M_to_M": {
#             "Argument Strength": 8,
#             "Summary Argument Strength": "Debaters presented strong evidence and relevant points, although some arguments were repetitive.",
#             "Engagement Style": 7,
#             "Summary Engagement Style": "Engagement was assertive with moments of empathy, though at times combative.",
#             "Tone Dynamics": 6,
#             "Summary Tone Dynamics": "Tone varied from supportive to critical, with some sarcastic exchanges.",
#             "Power Dynamics": 7,
#             "Summary Power Dynamics": "There were instances of interruptions, but overall a balanced exchange.",
#             "Total score (average of all)": 7.14,
#             "Total summary": "The interactions between male debaters were generally strong, with a good balance of argumentation and engagement."
#         },
#         "F_to_F": {
#             "Argument Strength": 9,
#             "Summary Argument Strength": "Arguments were well-structured and persuasive, addressing key issues effectively.",
#             "Engagement Style": 8,
#             "Summary Engagement Style": "Engagement was collaborative and respectful, with moments of challenge.",
#             "Tone Dynamics": 7,
#             "Summary Tone Dynamics": "Tone was predominantly supportive with constructive criticism.",
#             "Power Dynamics": 6,
#             "Summary Power Dynamics": "Interactions were mostly equal, with some instances of one speaker dominating.",
#             "Total score (average of all)": 7.57,
#             "Total summary": "Female debaters demonstrated strong collaborative engagement and effective argumentation."
#         },
#         "F_to_M": {
#             "Argument Strength": 8,
#             "Summary Argument Strength": "Female debaters presented strong arguments that effectively challenged male counterparts.",
#             "Engagement Style": 7,
#             "Summary Engagement Style": "Engagement was assertive, with females pushing back against male arguments.",
#             "Tone Dynamics": 6,
#             "Summary Tone Dynamics": "Tone varied, with a mix of assertiveness and cooperation.",
#             "Power Dynamics": 7,
#             "Summary Power Dynamics": "Power dynamics were somewhat balanced, with occasional interruptions.",
#             "Total score (average of all)": 6.86,
#             "Total summary": "Interactions between female and male debaters were strong, with women effectively challenging men."
#         },
#         "M_to_F": {
#             "Argument Strength": 7,
#             "Summary Argument Strength": "Male debaters presented relevant points but were occasionally dismissive.",
#             "Engagement Style": 6,
#             "Summary Engagement Style": "Engagement was assertive but sometimes defensive.",
#             "Tone Dynamics": 5,
#             "Summary Tone Dynamics": "Tone was often critical, with less supportiveness.",
#             "Power Dynamics": 8,
#             "Summary Power Dynamics": "Males tended to dominate the conversation, leading to occasional dismissive behavior.",
#             "Total score (average of all)": 6.50,
#             "Total summary": "Interactions showed a power imbalance, with males often overshadowing female contributions."
#         }
#     },
#     "overall_trends": "The debate showcased a dynamic interplay between male and female debaters, with females often challenging male arguments effectively. However, there were notable power dynamics where male debaters tended to dominate discussions.",
#     "final_score": 7.52
# }
# Overall score for analysis: 7.52

# %%
import pandas as pd

# Assuming analysis_result is already defined
episode_name = analysis_result['episode_name']

# Create scores_data DataFrame
scores_data = []
for interaction, details in analysis_result["interaction_analysis"].items():
    scores_data.append({
        "episode_name": episode_name,
        "interaction_type": interaction,
        "argument_strength": details["Argument Strength"],
        "summary_argument_strength": details["Summary Argument Strength"],
        "engagement_style": details["Engagement Style"],
        "summary_engagement_style": details["Summary Engagement Style"],
        "tone_dynamics": details["Tone Dynamics"],
        "summary_tone_dynamics": details["Summary Tone Dynamics"],
        "power_dynamics": details["Power Dynamics"],
        "summary_power_dynamics": details["Summary Power Dynamics"],
        "total_score": details["Total score (average of all)"],
        "total_summary": details["Total summary"]
    })

scores_df = pd.DataFrame(scores_data)

# Create participants_data DataFrame
participants_data = []
for participant in analysis_result["participants"]:
    participants_data.append({
        "episode_name": episode_name,
        "role": participant["role"],
        "gender": participant["gender"],
        "background": participant["background"]
    })

participants_df = pd.DataFrame(participants_data)

# Display the DataFrames
print("Scores DataFrame:")
print(scores_df)
print("\nParticipants DataFrame:")
print(participants_df)
# Out:
# Scores DataFrame:
#                                         episode_name interaction_type  \
# 0  Debatten - 8. okt. · Tidenes budsjett, men mis...           M_to_M
# 1  Debatten - 8. okt. · Tidenes budsjett, men mis...           F_to_F
# 2  Debatten - 8. okt. · Tidenes budsjett, men mis...           F_to_M
# 3  Debatten - 8. okt. · Tidenes budsjett, men mis...           M_to_F
#
#    argument_strength                          summary_argument_strength  \
# 0                  7  Both male debaters presented strong arguments ...
# 1                  8  The female experts provided insightful perspec...
# 2                  9  Female participants effectively challenged mal...
# 3                  7  Male participants presented strong arguments b...
#
#    engagement_style                           summary_engagement_style  \
# 0                 6  Engagement was generally assertive, with some ...
# 1                 7  Engagement was collaborative, with a focus on ...
# 2                 8  Highly engaging with a focus on challenging an...
# 3                 5  Engagement was somewhat uneven, with moments o...
#
#    tone_dynamics                              summary_tone_dynamics  \
# 0              5  Tone varied from critical to somewhat supporti...
# 1              6  Tone was supportive, with constructive criticism.
# 2              7  Tone was assertive and at times confrontationa...
# 3              6  Tone was serious, with some condescending unde...
#
#    power_dynamics                             summary_power_dynamics  \
# 0               6  There were moments of interruption, but overal...
# 1               5  There was a respectful exchange without signif...
# 2               6  Female participants held their ground well aga...
# 3               7  Males dominated the conversation, leading to o...
#
#    total_score                                      total_summary
# 0         6.50  The interaction between male debaters was asse...
# 1         6.50  The interaction between female experts was col...
# 2         7.50  The interaction between female and male partic...
# 3         6.25  The interaction was marked by a power imbalanc...
#
# Participants DataFrame:
#                                         episode_name       role gender  \
# 0  Debatten - 8. okt. · Tidenes budsjett, men mis...  Debater 1      M
# 1  Debatten - 8. okt. · Tidenes budsjett, men mis...   Expert 1      F
# 2  Debatten - 8. okt. · Tidenes budsjett, men mis...   Expert 2      M
# 3  Debatten - 8. okt. · Tidenes budsjett, men mis...   Expert 3      M
# 4  Debatten - 8. okt. · Tidenes budsjett, men mis...   Expert 4      M
# 5  Debatten - 8. okt. · Tidenes budsjett, men mis...   Expert 5      F
# 6  Debatten - 8. okt. · Tidenes budsjett, men mis...  Debater 2      F
# 7  Debatten - 8. okt. · Tidenes budsjett, men mis...  Debater 3      M
#
#                                           background
# 0                Political Editor, Swedish Newspaper
# 1       Professor, Institute of Social Economics, BI
# 2                   Professor, Social Economics, UIS
# 3        Professor Emeritus, Economic Institute, UiO
# 4                 Professor of Economic History, UiO
# 5  Senior Researcher, Public Health Institute and...
# 6           Former Finance Minister, Political Party
# 7   Current Auditor General, Former Finance Minister

# %%
# Save the DataFrames as separate Excel files in /content/ directory
scores_output_path = '/content/scores_analysis_results.xlsx'
participants_output_path = '/content/participants_analysis_results.xlsx'

# Save each DataFrame to an Excel file
scores_df.to_excel(scores_output_path, index=False)
participants_df.to_excel(participants_output_path, index=False)

(scores_output_path, participants_output_path)
# Out:
# ('/content/scores_analysis_results.xlsx',
#  '/content/participants_analysis_results.xlsx')

# %%
# Lag en matrise med poeng for interaksjoner der radene og kolonnene representerer kjønn (M og F)
gender_matrix = pd.DataFrame(index=["M", "F"], columns=["M", "F"])

# Fyll ut matrisen basert på interaksjonstype i DataFrame
for _, row in df_interaction_analysis.iterrows():
    if row['interaction_type'] == "M_to_M":
        gender_matrix.at["M", "M"] = row['score']
    elif row['interaction_type'] == "F_to_F":
        gender_matrix.at["F", "F"] = row['score']
    elif row['interaction_type'] == "F_to_M":
        gender_matrix.at["F", "M"] = row['score']
    elif row['interaction_type'] == "M_to_F":
        gender_matrix.at["M", "F"] = row['score']

# Vis matrisen
gender_matrix
# Out:
#    M  F
# M  7  7
# F  6  8

# %%
# !pip install yt-dlp
# Out:
# Collecting yt-dlp
#   Downloading yt_dlp-2024.11.4-py3-none-any.whl.metadata (172 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.1/172.1 kB 3.1 MB/s eta 0:00:00
# Downloading yt_dlp-2024.11.4-py3-none-any.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 36.2 MB/s eta 0:00:00
# Installing collected packages: yt-dlp
# Successfully installed yt-dlp-2024.11.4

# %% [markdown]
# #Bigdata

# %%
import requests
import yt_dlp
import os

# Base URL for NRK's API
base_url = "https://psapi.nrk.no"
series_url = f"{base_url}/tv/catalog/series/debatten"

# Antall episoder vi ønsker å hente, justert for å ignorere første
target_episodes = 9
episodes_needed = target_episodes + 1  # Hent 10 episoder, men ignorer den første
episodes_fetched = 0
page = 1

try:
    all_episodes = []

    # Hent episoder fra API-et
    while len(all_episodes) < episodes_needed:
        response = requests.get(series_url, params={"page": page})
        response.raise_for_status()
        series_data = response.json()

        if '_embedded' in series_data and 'instalments' in series_data['_embedded']:
            instalment_data = series_data['_embedded']['instalments']
            if '_embedded' in instalment_data and 'instalments' in instalment_data['_embedded']:
                episodes = instalment_data['_embedded']['instalments']
                all_episodes.extend(episodes)

                # Sjekk om det er flere sider
                if '_links' in instalment_data and 'next' in instalment_data['_links']:
                    page += 1
                else:
                    break  # Ingen flere sider
            else:
                break  # Ingen flere episoder funnet
        else:
            break  # Ingen flere episoder funnet

    # Fjern den første episoden og samle URL-ene for resten
    all_episodes = all_episodes[1:episodes_needed]  # Ignorer den første episoden

    # Samle URL-ene i en liste kalt URL
    URL = [f'https://tv.nrk.no/se?v={episode["prfId"]}' for episode in all_episodes]

    # Print en melding som viser hvor mange episoder som er hentet
    print(f"Episodes of Debatten (totalt {len(URL)}):")

    # Funksjon for å laste ned undertekster
    def download_subtitles(url, download_path):
        ydl_opts = {
            'writesubtitles': True,
            'subtitleslangs': ['nb-ttv'],  # Norsk bokmål TV-teksting
            'skip_download': True,  # Hopp over nedlasting av video
            'outtmpl': os.path.join(download_path, '%(title)s.%(ext)s'),
            'quiet': True,  # Reduserer mengden output til et minimum
            'no_warnings': True,  # Skjuler advarsler
            'postprocessors': [{
                'key': 'FFmpegSubtitlesConvertor',
                'format': 'srt',
            }],
            'logger': None,  # Fjerner logger-objektet for mindre støy
        }

        try:
            with yt_dlp.YoutubeDL(ydl_opts) as ydl:
                ydl.download([url])
            print(f"Subtitles downloaded for URL: {url}")
            return True  # Returner True hvis nedlasting var vellykket
        except Exception as e:
            print(f"En feil oppstod for {url}: {e}")
            return False  # Returner False hvis det oppstod en feil

    # Opprett mappe for lagring av undertekster
    download_path = os.path.join(os.getcwd(), "Debatten_subtitles")
    os.makedirs(download_path, exist_ok=True)

    # Last ned undertekster for hver URL i listen
    valid_urls = []
    for i, url in enumerate(URL):
        success = download_subtitles(url, download_path)
        if not success:
            print("Prøver neste tilgjengelige episode...")
            continue  # Gå videre til neste episode
        valid_urls.append(url)

    if len(valid_urls) < target_episodes:
        print(f"Kun {len(valid_urls)} episoder ble lastet ned vellykket.")
    else:
        print("All episodes fetched sucsessfully.")

except requests.RequestException as e:
    print(f"En feil oppstod ved henting av data: {e}")
# Out:
# Episodes of Debatten (totalt 9):
# Subtitles downloaded for URL: https://tv.nrk.no/se?v=NNFA51110724
# Subtitles downloaded for URL: https://tv.nrk.no/se?v=NNFA51103124
# Subtitles downloaded for URL: https://tv.nrk.no/se?v=NNFA51102924
# Subtitles downloaded for URL: https://tv.nrk.no/se?v=NNFA51102424
# Subtitles downloaded for URL: https://tv.nrk.no/se?v=NNFA51102224
# Subtitles downloaded for URL: https://tv.nrk.no/se?v=NNFA51101724
# Subtitles downloaded for URL: https://tv.nrk.no/se?v=NNFA51101524
# Subtitles downloaded for URL: https://tv.nrk.no/se?v=NNFA51101024
# Subtitles downloaded for URL: https://tv.nrk.no/se?v=NNFA51100824
# All episodes fetched sucsessfully.

# %%
import os
import json
import openai


# Katalog som inneholder VTT-filer
directory_path = "Debatten_subtitles"

# Liste for å lagre analyseresultater for alle filer
analysis_results = []

# Iterer gjennom alle VTT-filer i katalogen
for filename in os.listdir(directory_path):
    if filename.endswith(".vtt"):
        file_path = os.path.join(directory_path, filename)

        # Les data fra VTT-filen
        with open(file_path, "r", encoding="UTF-8") as file:
            data = file.read()

        # Opprett meldingene for forespørselen
        messages = [
            {
                "role": "system",
                "content": """
                    You are an expert in language analysis and interaction analysis in discussions, with a focus on identifying all unique speakers in dialogue.
                    Your task is to analyze the entire text provided and:

                    1. Identify and label each unique speaker based on their speech patterns, contextual cues, or dialogue markers.
                    2. Assign a unique identifier to each speaker (e.g., "Speaker 1," "Speaker 2,", "Debater 1", "Debater 2," or "Expert 1" etc.) and determine their gender (M/F) when possible based on context. Not their real name.
                    3. Include all participants present in the text and ensure no speaker is omitted. Do not limit the identification to a predefined number of examples.
                    4. Look for shifts in tone, specific language usage, or structural cues in the dialogue to differentiate speakers.
                    5. Comprehensive Interaction Analysis: Evaluate and score the interactions between all debaters, not just a sample. This analysis should include every interaction and response in the provided text to ensure an accurate and holistic assessment of how each participant interacts with others.
                      Scoring Categories:
                        -Argument Strength: Rate the clarity, relevance, and persuasiveness of each participant’s arguments throughout the discussion.
                        -Engagement Style: Assess interaction qualities such as empathy, assertiveness, defensiveness, or conciliation as demonstrated across all dialogue.
                        -Tone Dynamics: Identify variations in tone such as supportive, critical, sarcastic, or enthusiastic exchanges, considering the entire range of interactions.
                        -Power Dynamics: Score power displays or imbalances, such as interruptions, speaking over others, or dismissive responses, over the entire debate.
                    6. Use an analysis model: Analyze how gender patterns may influence treatment in interactions, while controlling for other variables.
                    7. Scoring: All scoring should be in the interval 1-10, 1 is the lowest and 10 is the highest.
                    8. Final Scoring: Combine scores across all categories for each participant to assign a final score reflecting their overall performance and engagement style in the full debate.

                    Analyze the interactions between all participants and categorize them into gender-based combinations (M to M, F to M, F to F, M to F). Ensure the output is presented in JSON format as follows:
                    {
                        "episode_name": "<generated_name>",
                        "participants": [
                            {
                                "role": "<role>",
                                "gender": "<M/F>",
                                "background": "(party affiliation, organization, etc.)"
                            }
                        ],
                        "interaction_analysis": {
                            "M_to_M": {
                                "Argument Strenght": <number>,
                                "Summary Argument Strenght": <summary>,
                                "Engagement Style": <number>,
                                "Summary Engagement style": <summary>,
                                "Tone Dynamics": <number>,
                                "Summary Tone Dynamics": <summary>,
                                "Power Dynamics": <number>,
                                "Summary Power Dynamics": <summary>,
                                "Total score (average of all)": <number>,
                                "Total summary": "<summary>"

                            },
                            "F_to_F": {
                                "Argument Strenght": <number>,
                                "Summary Argument Strenght": <summary>,
                                "Engagement Style": <number>,
                                "Summary Engagement style": <summary>,
                                "Tone Dynamics": <number>,
                                "Summary Tone Dynamics": <summary>,
                                "Power Dynamics": <number>,
                                "Summary Power Dynamics": <summary>,
                                "Total score (average of all)": <number>,
                                "Total summary": "<summary>"
                            },
                            "F_to_M": {
                                "Argument Strenght": <number>,
                                "Summary Argument Strenght": <summary>,
                                "Engagement Style": <number>,
                                "Summary Engagement style": <summary>,
                                "Tone Dynamics": <number>,
                                "Summary Tone Dynamics": <summary>,
                                "Power Dynamics": <number>,
                                "Summary Power Dynamics": <summary>,
                                "Total score (average of all)": <number>,
                                "Total summary": "<summary>"
                            },
                            "M_to_F": {
                                "Argument Strenght": <number>,
                                "Summary Argument Strenght": <summary>,
                                "Engagement Style": <number>,
                                "Summary Engagement style": <summary>,
                                "Tone Dynamics": <number>,
                                "Summary Tone Dynamics": <summary>,
                                "Power Dynamics": <number>,
                                "Summary Power Dynamics": <summary>,
                                "Total score (average of all)": <number>,
                                "Total summary": "<summary>"
                            }
                        },
                        "overall_trends": "<description>",
                        "final_score": <number>
                    }
                """
            },
            {
                "role": "user",
                "content": f"""
                    Analyze the text below and categorize participants as “debater 1,” “debater 2,” “expert 1,” etc not their real name.
                    Evaluate how they interact with each other in all gender combinations (M to M, F to M, F to F, M to F).
                    Include all participants and do not include the moderator in the analysis.
                    In English only.

                    <data>{data}</data>

                    Response:
                """
            }
        ]

        # Forespørsel til OpenAI API
        completion = client.chat.completions.create(
        model="gpt-4o-mini",  # Replace with your actual model name
        messages=messages,
        temperature=0.5,
        response_format={"type": "json_object"},  # Guarantees that the response is in JSON format
)

        # Analyser og lagre resultatet
        if completion.choices[0].message.content:
            analysis_result = json.loads(completion.choices[0].message.content)
            analysis_result["episode_name"] = filename.replace(".vtt", "")  # Legg til episodenavn
            analysis_results.append(analysis_result)

            # Print melding når analysen er ferdig for en episode
            print(f"Finished analyzing: {filename}")

# Print den endelige JSON-variabelen som inneholder alle resultater
final_json_result = json.dumps(analysis_results, indent=4)
print(final_json_result)
# Out:
# Finished analyzing: Debatten - 10. okt. · Bløffebudsjett, mener opposisjonen.nb-ttv.vtt
# Finished analyzing: Debatten - 22. okt. · Milliardene flyr i havvinden.nb-ttv.vtt
# Finished analyzing: Debatten - 15. okt. · Skoler legges ned, bygder dør.nb-ttv.vtt
# Finished analyzing: Debatten - Torsdag · «Falsk same»？.nb-ttv.vtt
# Finished analyzing: Debatten - 29. okt. · Du blir lurt.nb-ttv.vtt
# Finished analyzing: Debatten - 24. okt. · Unge sender Ap mot sperregrensa.nb-ttv.vtt
# Finished analyzing: Debatten - 31. okt. · Milliarder til norske batterier.nb-ttv.vtt
# Finished analyzing: Debatten - 17. okt. · Slik kan du spare på maten.nb-ttv.vtt
# Finished analyzing: Debatten - 8. okt. · Tidenes budsjett, men misnøyen vokser.nb-ttv.vtt
# [
#     {
#         "episode_name": "Debatten - 10. okt. \u00b7 Bl\u00f8ffebudsjett, mener opposisjonen.nb-ttv",
#         "participants": [
#             {
#                 "role": "Debater 1",
#                 "gender": "M",
#                 "background": "Prime Minister, Labour Party"
#             },
#             {
#                 "role": "Debater 2",
#                 "gender": "F",
#                 "background": "Leader, Conservative Party"
#             },
#             {
#                 "role": "Debater 3",
#                 "gender": "F",
#                 "background": "Leader, Socialist Left Party"
#             },
#             {
#                 "role": "Debater 4",
#                 "gender": "F",
#                 "background": "Leader, Christian Democratic Party"
#             },
#             {
#                 "role": "Debater 5",
#                 "gender": "M",
#                 "background": "Leader, Progress Party"
#             },
#             {
#                 "role": "Debater 6",
#                 "gender": "F",
#                 "background": "Leader, Red Party"
#             },
#             {
#                 "role": "Debater 7",
#                 "gender": "M",
#                 "background": "Leader, Centre Party"
#             },
#             {
#                 "role": "Expert 1",
#                 "gender": "M",
#                 "background": "Political Analyst"
#             }
#         ],
#         "interaction_analysis": {
#             "M_to_M": {
#                 "Argument Strength": 7,
#                 "Summary Argument Strength": "Arguments were generally clear and persuasive, focusing on economic and social issues.",
#                 "Engagement Style": 6,
#                 "Summary Engagement Style": "Engagement was assertive, with moments of defensiveness.",
#                 "Tone Dynamics": 5,
#                 "Summary Tone Dynamics": "Tone varied between critical and supportive, reflecting the contentious nature of the debate.",
#                 "Power Dynamics": 6,
#                 "Summary Power Dynamics": "No significant power imbalances, but occasional interruptions noted.",
#                 "Total score (average of all)": 6,
#                 "Total summary": "Interactions were balanced, with both sides presenting strong arguments."
#             },
#             "F_to_F": {
#                 "Argument Strength": 8,
#                 "Summary Argument Strength": "Arguments were well-structured and compelling, addressing key issues effectively.",
#                 "Engagement Style": 7,
#                 "Summary Engagement Style": "Engagement was collaborative, with a focus on shared values.",
#                 "Tone Dynamics": 6,
#                 "Summary Tone Dynamics": "Tone was generally supportive, with some critical exchanges.",
#                 "Power Dynamics": 5,
#                 "Summary Power Dynamics": "Power dynamics were relatively equal, with both sides contributing equally.",
#                 "Total score (average of all)": 6.5,
#                 "Total summary": "Interactions were constructive, showcasing effective collaboration."
#             },
#             "F_to_M": {
#                 "Argument Strength": 9,
#                 "Summary Argument Strength": "Arguments presented by female debaters were particularly strong and persuasive.",
#                 "Engagement Style": 8,
#                 "Summary Engagement Style": "Engagement was assertive and confident, with effective rebuttals.",
#                 "Tone Dynamics": 7,
#                 "Summary Tone Dynamics": "Tone was assertive and occasionally confrontational, reflecting a strong debate.",
#                 "Power Dynamics": 6,
#                 "Summary Power Dynamics": "Some power imbalances noted, with female debaters often holding their ground.",
#                 "Total score (average of all)": 7.5,
#                 "Total summary": "Female debaters showed strong performance, effectively challenging male counterparts."
#             },
#             "M_to_F": {
#                 "Argument Strength": 6,
#                 "Summary Argument Strength": "Arguments were clear but occasionally lacked depth.",
#                 "Engagement Style": 5,
#                 "Summary Engagement Style": "Engagement was somewhat defensive, with less collaboration.",
#                 "Tone Dynamics": 5,
#                 "Summary Tone Dynamics": "Tone was generally neutral, with moments of tension.",
#                 "Power Dynamics": 6,
#                 "Summary Power Dynamics": "Male debaters maintained control, but female debaters effectively challenged them.",
#                 "Total score (average of all)": 5.5,
#                 "Total summary": "Interactions were balanced, but male debaters often dominated the conversation."
#             }
#         },
#         "overall_trends": "The debate showcased a mix of assertiveness and collaboration among participants, with female debaters particularly excelling in argument strength and engagement style. Male debaters maintained a more defensive stance at times, but overall, the interactions were balanced and constructive.",
#         "final_score": 6.5
#     },
#     {
#         "episode_name": "Debatten - 22. okt. \u00b7 Milliardene flyr i havvinden.nb-ttv",
#         "participants": [
#             {
#                 "role": "Debater 1",
#                 "gender": "M",
#                 "background": "Politician advocating for offshore wind"
#             },
#             {
#                 "role": "Debater 2",
#                 "gender": "M",
#                 "background": "Energy director at NVE"
#             },
#             {
#                 "role": "Expert 1",
#                 "gender": "M",
#                 "background": "Professor at NTNU"
#             },
#             {
#                 "role": "Expert 2",
#                 "gender": "M",
#                 "background": "Research leader at DNV"
#             },
#             {
#                 "role": "Debater 3",
#                 "gender": "M",
#                 "background": "Leader of Motvind Norway"
#             },
#             {
#                 "role": "Debater 4",
#                 "gender": "F",
#                 "background": "CEO of Fornybar Norge"
#             },
#             {
#                 "role": "Debater 5",
#                 "gender": "M",
#                 "background": "Editor at Europower"
#             },
#             {
#                 "role": "Debater 6",
#                 "gender": "M",
#                 "background": "CEO of Deep Wind Offshore"
#             },
#             {
#                 "role": "Debater 7",
#                 "gender": "M",
#                 "background": "CEO of IKM-Gruppen"
#             }
#         ],
#         "interaction_analysis": {
#             "M_to_M": {
#                 "Argument Strength": 8,
#                 "Summary Argument Strength": "Strong arguments presented with empirical backing.",
#                 "Engagement Style": 7,
#                 "Summary Engagement Style": "Assertive and competitive with moments of collaboration.",
#                 "Tone Dynamics": 6,
#                 "Summary Tone Dynamics": "Mostly serious with some critical exchanges.",
#                 "Power Dynamics": 5,
#                 "Summary Power Dynamics": "Balanced, with some interruptions but generally respectful.",
#                 "Total score (average of all)": 6.5,
#                 "Total summary": "The male participants engaged in a robust debate, presenting strong arguments but occasionally interrupting each other."
#             },
#             "F_to_F": {
#                 "Argument Strength": 7,
#                 "Summary Argument Strength": "Arguments were clear and well-structured.",
#                 "Engagement Style": 8,
#                 "Summary Engagement Style": "Supportive and constructive.",
#                 "Tone Dynamics": 7,
#                 "Summary Tone Dynamics": "Positive and collaborative tone.",
#                 "Power Dynamics": 6,
#                 "Summary Power Dynamics": "Respectful exchanges with equal participation.",
#                 "Total score (average of all)": 6.5,
#                 "Total summary": "The female participants displayed a collaborative approach, effectively supporting each other's points."
#             },
#             "F_to_M": {
#                 "Argument Strength": 8,
#                 "Summary Argument Strength": "Strong and relevant points made by female participants.",
#                 "Engagement Style": 6,
#                 "Summary Engagement Style": "Assertive but sometimes defensive.",
#                 "Tone Dynamics": 6,
#                 "Summary Tone Dynamics": "Serious with some moments of tension.",
#                 "Power Dynamics": 5,
#                 "Summary Power Dynamics": "Some power imbalance noted, but generally respectful.",
#                 "Total score (average of all)": 6.5,
#                 "Total summary": "Female participants effectively challenged male counterparts, although some defensiveness was observed."
#             },
#             "M_to_F": {
#                 "Argument Strength": 7,
#                 "Summary Argument Strength": "Arguments presented by male participants were mostly strong.",
#                 "Engagement Style": 7,
#                 "Summary Engagement Style": "Assertive with occasional support.",
#                 "Tone Dynamics": 5,
#                 "Summary Tone Dynamics": "Mixed tone with some critical remarks.",
#                 "Power Dynamics": 6,
#                 "Summary Power Dynamics": "Generally respectful but with occasional interruptions.",
#                 "Total score (average of all)": 6.25,
#                 "Total summary": "Male participants engaged assertively with female participants, showing a mix of support and challenge."
#             }
#         },
#         "overall_trends": "The debate featured a mix of assertiveness and collaboration among participants, with male participants generally displaying more competitive engagement styles. Female participants contributed strong arguments and maintained a supportive tone, but occasionally faced interruptions.",
#         "final_score": 6.5
#     },
#     {
#         "episode_name": "Debatten - 15. okt. \u00b7 Skoler legges ned, bygder d\u00f8r.nb-ttv",
#         "participants": [
#             {
#                 "role": "Debater 1",
#                 "gender": "M",
#                 "background": "Finansminister, Sp-leder"
#             },
#             {
#                 "role": "Debater 2",
#                 "gender": "M",
#                 "background": "Fylkesordf\u00f8rer, Ap"
#             },
#             {
#                 "role": "Debater 3",
#                 "gender": "F",
#                 "background": "Forsker, Engasjert forelder"
#             },
#             {
#                 "role": "Debater 4",
#                 "gender": "F",
#                 "background": "Helsesista, Aktivist"
#             },
#             {
#                 "role": "Debater 5",
#                 "gender": "M",
#                 "background": "Kokk, Gr\u00fcnder"
#             },
#             {
#                 "role": "Debater 6",
#                 "gender": "F",
#                 "background": "Ungdomsrepresentant"
#             },
#             {
#                 "role": "Debater 7",
#                 "gender": "M",
#                 "background": "Ordf\u00f8rer, Frp"
#             },
#             {
#                 "role": "Debater 8",
#                 "gender": "F",
#                 "background": "Kunnskapsminister, Ap"
#             },
#             {
#                 "role": "Debater 9",
#                 "gender": "M",
#                 "background": "Stortingsrepresentant, H\u00f8yre"
#             },
#             {
#                 "role": "Debater 10",
#                 "gender": "F",
#                 "background": "Kommentator, Aftenposten"
#             },
#             {
#                 "role": "Debater 11",
#                 "gender": "M",
#                 "background": "Sjefredakt\u00f8r, Tr\u00f8nderavisa"
#             }
#         ],
#         "interaction_analysis": {
#             "M_to_M": {
#                 "Argument Strength": 7,
#                 "Summary Argument Strength": "Arguments were generally clear but occasionally lacked depth.",
#                 "Engagement Style": 6,
#                 "Summary Engagement style": "Assertive but sometimes dismissive.",
#                 "Tone Dynamics": 6,
#                 "Summary Tone Dynamics": "Tone varied from critical to conciliatory.",
#                 "Power Dynamics": 7,
#                 "Summary Power Dynamics": "Some interruptions noted, indicating a power struggle.",
#                 "Total score (average of all)": 6.4,
#                 "Total summary": "Overall, male interactions showed a balance of assertiveness and engagement but with noticeable interruptions."
#             },
#             "F_to_F": {
#                 "Argument Strength": 8,
#                 "Summary Argument Strength": "Arguments were well-articulated with strong emotional appeals.",
#                 "Engagement Style": 9,
#                 "Summary Engagement style": "Highly empathetic and supportive.",
#                 "Tone Dynamics": 8,
#                 "Summary Tone Dynamics": "Supportive and passionate exchanges.",
#                 "Power Dynamics": 8,
#                 "Summary Power Dynamics": "Balanced exchanges with mutual respect.",
#                 "Total score (average of all)": 8.2,
#                 "Total summary": "Female interactions were characterized by strong emotional resonance and collaborative engagement."
#             },
#             "F_to_M": {
#                 "Argument Strength": 8,
#                 "Summary Argument Strength": "Arguments presented were strong and relevant.",
#                 "Engagement Style": 7,
#                 "Summary Engagement style": "Assertive with moments of vulnerability.",
#                 "Tone Dynamics": 7,
#                 "Summary Tone Dynamics": "Generally respectful but occasionally confrontational.",
#                 "Power Dynamics": 6,
#                 "Summary Power Dynamics": "Some power imbalances, with men occasionally dominating discussions.",
#                 "Total score (average of all)": 7.0,
#                 "Total summary": "Female to male interactions showed a strong presentation of arguments, though some power dynamics favored male speakers."
#             },
#             "M_to_F": {
#                 "Argument Strength": 7,
#                 "Summary Argument Strength": "Arguments were relevant but sometimes lacked clarity.",
#                 "Engagement Style": 5,
#                 "Summary Engagement style": "Occasionally defensive and dismissive.",
#                 "Tone Dynamics": 6,
#                 "Summary Tone Dynamics": "Tone ranged from supportive to condescending.",
#                 "Power Dynamics": 7,
#                 "Summary Power Dynamics": "Men tended to dominate discussions, leading to some dismissive tones.",
#                 "Total score (average of all)": 6.3,
#                 "Total summary": "Male to female interactions were often characterized by a lack of engagement and occasional dismissiveness."
#             }
#         },
#         "overall_trends": "The debate showcased a mix of assertiveness and emotional engagement, with female participants displaying strong collaborative efforts. Male participants often exhibited more defensive and dismissive tendencies, leading to power imbalances.",
#         "final_score": 7.0
#     },
#     {
#         "episode_name": "Debatten - Torsdag \u00b7 \u00abFalsk same\u00bb\uff1f.nb-ttv",
#         "participants": [
#             {
#                 "role": "Debater 1",
#                 "gender": "F",
#                 "background": "Stortinget representative, Senterpartiet"
#             },
#             {
#                 "role": "Debater 2",
#                 "gender": "M",
#                 "background": "Director, NRK S\u00e1pmi"
#             },
#             {
#                 "role": "Expert 1",
#                 "gender": "F",
#                 "background": "Former Sametinget representative, NSR"
#             },
#             {
#                 "role": "Expert 2",
#                 "gender": "M",
#                 "background": "Professor, UIT"
#             },
#             {
#                 "role": "Debater 3",
#                 "gender": "M",
#                 "background": "Stortingsrepresentant, Frp"
#             },
#             {
#                 "role": "Debater 4",
#                 "gender": "F",
#                 "background": "Member of Nordkalottfolket, former mayor"
#             },
#             {
#                 "role": "Debater 5",
#                 "gender": "M",
#                 "background": "Senior researcher, OsloMet"
#             },
#             {
#                 "role": "Debater 6",
#                 "gender": "M",
#                 "background": "Plenumsleder, Sametinget, Arbeiderpartiet"
#             }
#         ],
#         "interaction_analysis": {
#             "M_to_M": {
#                 "Argument Strength": 7,
#                 "Summary Argument Strength": "Arguments presented by male participants were generally clear and relevant, addressing the complexities of Sami identity and rights.",
#                 "Engagement Style": 6,
#                 "Summary Engagement Style": "Interactions were assertive but sometimes defensive, particularly when discussing identity criteria.",
#                 "Tone Dynamics": 5,
#                 "Summary Tone Dynamics": "Tone varied from critical to conciliatory, with some sarcasm noted.",
#                 "Power Dynamics": 6,
#                 "Summary Power Dynamics": "Power dynamics were somewhat balanced, with occasional interruptions noted.",
#                 "Total score (average of all)": 6,
#                 "Total summary": "Male interactions displayed a mix of assertiveness and defensiveness, with clear arguments but some tension."
#             },
#             "F_to_F": {
#                 "Argument Strength": 8,
#                 "Summary Argument Strength": "Female participants articulated strong arguments regarding identity and cultural heritage.",
#                 "Engagement Style": 7,
#                 "Summary Engagement Style": "Engagement was empathetic and supportive, focusing on shared experiences.",
#                 "Tone Dynamics": 8,
#                 "Summary Tone Dynamics": "Tone was generally supportive and passionate, highlighting emotional connections.",
#                 "Power Dynamics": 7,
#                 "Summary Power Dynamics": "Female participants exhibited collaborative dynamics, although some competitive moments were present.",
#                 "Total score (average of all)": 7.5,
#                 "Total summary": "Female interactions were characterized by strong arguments and supportive engagement."
#             },
#             "F_to_M": {
#                 "Argument Strength": 9,
#                 "Summary Argument Strength": "Female participants presented compelling arguments that challenged male perspectives effectively.",
#                 "Engagement Style": 8,
#                 "Summary Engagement Style": "Engagement was assertive and often confrontational, particularly on issues of identity.",
#                 "Tone Dynamics": 7,
#                 "Summary Tone Dynamics": "Tone was assertive, sometimes critical, reflecting the seriousness of the topics discussed.",
#                 "Power Dynamics": 6,
#                 "Summary Power Dynamics": "Power dynamics showed some imbalance with females asserting themselves strongly against male perspectives.",
#                 "Total score (average of all)": 7.5,
#                 "Total summary": "Interactions showed strong female engagement against male viewpoints, with compelling arguments."
#             },
#             "M_to_F": {
#                 "Argument Strength": 7,
#                 "Summary Argument Strength": "Male participants provided relevant arguments but sometimes lacked depth compared to female counterparts.",
#                 "Engagement Style": 5,
#                 "Summary Engagement Style": "Engagement was at times dismissive, reflecting a power imbalance.",
#                 "Tone Dynamics": 6,
#                 "Summary Tone Dynamics": "Tone varied from critical to defensive, particularly when challenged.",
#                 "Power Dynamics": 5,
#                 "Summary Power Dynamics": "Male participants occasionally dominated the conversation, leading to interruptions.",
#                 "Total score (average of all)": 5.75,
#                 "Total summary": "Male to female interactions showed some imbalance, with males occasionally dismissive."
#             }
#         },
#         "overall_trends": "The debate showcased a strong emphasis on identity and cultural heritage, with female participants often presenting more compelling arguments. Male participants were generally assertive but sometimes defensive, indicating a complex dynamic.",
#         "final_score": 6.5
#     },
#     {
#         "episode_name": "Debatten - 29. okt. \u00b7 Du blir lurt.nb-ttv",
#         "participants": [
#             {
#                 "role": "Debater 1",
#                 "gender": "F",
#                 "background": "Medical student at UiO"
#             },
#             {
#                 "role": "Expert 1",
#                 "gender": "M",
#                 "background": "Director at Nasjonal kommunikasjonsmyndighet (Nkom)"
#             },
#             {
#                 "role": "Debater 2",
#                 "gender": "M",
#                 "background": "Board member of the school parent council"
#             },
#             {
#                 "role": "Expert 2",
#                 "gender": "F",
#                 "background": "CEO of Telenor Norway"
#             },
#             {
#                 "role": "Debater 3",
#                 "gender": "F",
#                 "background": "Leader in combating economic crime at Sparebank 1"
#             },
#             {
#                 "role": "Expert 3",
#                 "gender": "M",
#                 "background": "Leader of Financial Cyber Crime Center at DNB"
#             },
#             {
#                 "role": "Debater 4",
#                 "gender": "F",
#                 "background": "Helle Jacobsen, victim of home visit scam"
#             },
#             {
#                 "role": "Debater 5",
#                 "gender": "M",
#                 "background": "Steinar Vadla Risa, security chief for Urmaker Christensen"
#             },
#             {
#                 "role": "Debater 6",
#                 "gender": "M",
#                 "background": "Marius Jordet, ethical hacker"
#             },
#             {
#                 "role": "Expert 4",
#                 "gender": "M",
#                 "background": "Director of \u00d8kokrim"
#             },
#             {
#                 "role": "Expert 5",
#                 "gender": "M",
#                 "background": "Eirik Bogsnes, Group Director at Strawberry"
#             }
#         ],
#         "interaction_analysis": {
#             "M_to_M": {
#                 "Argument Strength": 7,
#                 "Summary Argument Strength": "Both experts presented solid arguments regarding digital security and fraud prevention.",
#                 "Engagement Style": 6,
#                 "Summary Engagement style": "Interactions were generally assertive, with some defensive moments.",
#                 "Tone Dynamics": 7,
#                 "Summary Tone Dynamics": "The tone was serious and informative, with occasional urgency.",
#                 "Power Dynamics": 6,
#                 "Summary Power Dynamics": "Power dynamics were balanced, with some interruptions but overall respectful.",
#                 "Total score (average of all)": 6.5,
#                 "Total summary": "The male interactions were generally strong and informative, with a few moments of defensiveness."
#             },
#             "F_to_F": {
#                 "Argument Strength": 8,
#                 "Summary Argument Strength": "The female participants provided insightful personal experiences and solid arguments.",
#                 "Engagement Style": 7,
#                 "Summary Engagement style": "Engagement was empathetic and supportive, enhancing the discussion.",
#                 "Tone Dynamics": 8,
#                 "Summary Tone Dynamics": "The tone was compassionate and serious, reflecting the gravity of the issues discussed.",
#                 "Power Dynamics": 7,
#                 "Summary Power Dynamics": "Power dynamics were generally equal, with good support among female participants.",
#                 "Total score (average of all)": 7.5,
#                 "Total summary": "Female interactions were strong, empathetic, and collaborative."
#             },
#             "F_to_M": {
#                 "Argument Strength": 9,
#                 "Summary Argument Strength": "Female participants effectively challenged male experts, presenting strong counterarguments.",
#                 "Engagement Style": 8,
#                 "Summary Engagement style": "Engagement was assertive, with a focus on collaboration and understanding.",
#                 "Tone Dynamics": 8,
#                 "Summary Tone Dynamics": "The tone was assertive yet respectful, fostering a productive dialogue.",
#                 "Power Dynamics": 8,
#                 "Summary Power Dynamics": "Power dynamics were favorable for female participants, showing assertiveness.",
#                 "Total score (average of all)": 8.25,
#                 "Total summary": "Interactions were strong, with female participants effectively engaging male counterparts."
#             },
#             "M_to_F": {
#                 "Argument Strength": 7,
#                 "Summary Argument Strength": "Male participants provided relevant information but were occasionally dismissive.",
#                 "Engagement Style": 6,
#                 "Summary Engagement style": "Engagement was sometimes defensive, with a need for more openness.",
#                 "Tone Dynamics": 6,
#                 "Summary Tone Dynamics": "The tone was informative but could be critical at times.",
#                 "Power Dynamics": 5,
#                 "Summary Power Dynamics": "Power dynamics showed some imbalance, with males occasionally interrupting.",
#                 "Total score (average of all)": 6,
#                 "Total summary": "Male interactions with female participants were informative but lacked some respect."
#             }
#         },
#         "overall_trends": "The debate showcased a mix of strong female voices challenging male experts, reflecting a growing trend of empowerment in discussions about digital security.",
#         "final_score": 7.25
#     },
#     {
#         "episode_name": "Debatten - 24. okt. \u00b7 Unge sender Ap mot sperregrensa.nb-ttv",
#         "participants": [
#             {
#                 "role": "Debater 1",
#                 "gender": "M",
#                 "background": "Leader of the youth wing of a political party (Fpu)"
#             },
#             {
#                 "role": "Debater 2",
#                 "gender": "M",
#                 "background": "Leader of the youth wing of a political party (AUF)"
#             },
#             {
#                 "role": "Expert 1",
#                 "gender": "M",
#                 "background": "Political analyst from Norstat"
#             },
#             {
#                 "role": "Expert 2",
#                 "gender": "M",
#                 "background": "Director of Ipsos"
#             }
#         ],
#         "interaction_analysis": {
#             "M_to_M": {
#                 "Argument Strength": 8,
#                 "Summary Argument Strength": "Both debaters presented clear and relevant arguments about the youth's political preferences and societal issues.",
#                 "Engagement Style": 7,
#                 "Summary Engagement Style": "Engagement was assertive, with both debaters defending their positions vigorously.",
#                 "Tone Dynamics": 6,
#                 "Summary Tone Dynamics": "The tone was largely serious and critical, with moments of sarcasm.",
#                 "Power Dynamics": 5,
#                 "Summary Power Dynamics": "There were a few interruptions, but generally, both debaters maintained a balanced exchange.",
#                 "Total score (average of all)": 6.5,
#                 "Total summary": "The interaction was strong, with both debaters effectively presenting their views."
#             },
#             "F_to_F": {
#                 "Argument Strength": 0,
#                 "Summary Argument Strength": "No female participants were present to engage in this category.",
#                 "Engagement Style": 0,
#                 "Summary Engagement Style": "No female participants were present to engage in this category.",
#                 "Tone Dynamics": 0,
#                 "Summary Tone Dynamics": "No female participants were present to engage in this category.",
#                 "Power Dynamics": 0,
#                 "Summary Power Dynamics": "No female participants were present to engage in this category.",
#                 "Total score (average of all)": 0,
#                 "Total summary": "No interactions to evaluate."
#             },
#             "F_to_M": {
#                 "Argument Strength": 0,
#                 "Summary Argument Strength": "No female participants were present to engage in this category.",
#                 "Engagement Style": 0,
#                 "Summary Engagement Style": "No female participants were present to engage in this category.",
#                 "Tone Dynamics": 0,
#                 "Summary Tone Dynamics": "No female participants were present to engage in this category.",
#                 "Power Dynamics": 0,
#                 "Summary Power Dynamics": "No female participants were present to engage in this category.",
#                 "Total score (average of all)": 0,
#                 "Total summary": "No interactions to evaluate."
#             },
#             "M_to_F": {
#                 "Argument Strength": 0,
#                 "Summary Argument Strength": "No female participants were present to engage in this category.",
#                 "Engagement Style": 0,
#                 "Summary Engagement Style": "No female participants were present to engage in this category.",
#                 "Tone Dynamics": 0,
#                 "Summary Tone Dynamics": "No female participants were present to engage in this category.",
#                 "Power Dynamics": 0,
#                 "Summary Power Dynamics": "No female participants were present to engage in this category.",
#                 "Total score (average of all)": 0,
#                 "Total summary": "No interactions to evaluate."
#             }
#         },
#         "overall_trends": "The discussion highlighted a significant divide in political preferences among youth, with both male debaters articulating the concerns of their respective parties regarding youth engagement and societal issues. The lack of female representation limited the diversity of perspectives.",
#         "final_score": 6.5
#     },
#     {
#         "episode_name": "Debatten - 31. okt. \u00b7 Milliarder til norske batterier.nb-ttv",
#         "participants": [
#             {
#                 "role": "Debater 1",
#                 "gender": "M",
#                 "background": "Politician, Labour Party"
#             },
#             {
#                 "role": "Debater 2",
#                 "gender": "F",
#                 "background": "Minister of Trade, Labour Party"
#             },
#             {
#                 "role": "Expert 1",
#                 "gender": "M",
#                 "background": "Partner at Rystad Energy"
#             },
#             {
#                 "role": "Expert 2",
#                 "gender": "M",
#                 "background": "CEO of Morrow Batteries"
#             },
#             {
#                 "role": "Expert 3",
#                 "gender": "M",
#                 "background": "Investor"
#             },
#             {
#                 "role": "Expert 4",
#                 "gender": "M",
#                 "background": "Professor, NTNU"
#             },
#             {
#                 "role": "Expert 5",
#                 "gender": "F",
#                 "background": "CEO of Nysn\u00f8"
#             },
#             {
#                 "role": "Debater 3",
#                 "gender": "M",
#                 "background": "Representative, Conservative Party"
#             },
#             {
#                 "role": "Debater 4",
#                 "gender": "F",
#                 "background": "Minister of Industry, Labour Party"
#             }
#         ],
#         "interaction_analysis": {
#             "M_to_M": {
#                 "Argument Strength": 8,
#                 "Summary Argument Strength": "Both male debaters presented clear and relevant arguments regarding economic policies and green transition.",
#                 "Engagement Style": 7,
#                 "Summary Engagement Style": "Engagement was assertive, with moments of conciliation.",
#                 "Tone Dynamics": 6,
#                 "Summary Tone Dynamics": "The tone was mostly serious with some supportive exchanges.",
#                 "Power Dynamics": 7,
#                 "Summary Power Dynamics": "There were instances of interruptions, but overall a balanced exchange.",
#                 "Total score (average of all)": 7.5,
#                 "Total summary": "Male interactions were strong, with clear arguments and assertiveness."
#             },
#             "F_to_F": {
#                 "Argument Strength": 7,
#                 "Summary Argument Strength": "Both female experts effectively communicated their perspectives on language and clarity in political discourse.",
#                 "Engagement Style": 8,
#                 "Summary Engagement Style": "Engagement was empathetic and collaborative.",
#                 "Tone Dynamics": 7,
#                 "Summary Tone Dynamics": "The tone was supportive with a focus on constructive dialogue.",
#                 "Power Dynamics": 6,
#                 "Summary Power Dynamics": "Interactions were generally equal, with no significant power imbalances.",
#                 "Total score (average of all)": 7.0,
#                 "Total summary": "Female interactions were collaborative with a focus on improvement."
#             },
#             "F_to_M": {
#                 "Argument Strength": 8,
#                 "Summary Argument Strength": "The female debater presented strong arguments regarding the need for clarity in political language.",
#                 "Engagement Style": 8,
#                 "Summary Engagement Style": "Engagement was assertive and confident.",
#                 "Tone Dynamics": 7,
#                 "Summary Tone Dynamics": "The tone was assertive and at times critical.",
#                 "Power Dynamics": 7,
#                 "Summary Power Dynamics": "There were moments of challenge, but overall a balanced dynamic.",
#                 "Total score (average of all)": 7.5,
#                 "Total summary": "Female to male interactions were assertive and impactful."
#             },
#             "M_to_F": {
#                 "Argument Strength": 7,
#                 "Summary Argument Strength": "Male debaters provided relevant arguments but sometimes overshadowed the female perspectives.",
#                 "Engagement Style": 6,
#                 "Summary Engagement Style": "Engagement was sometimes defensive from male participants.",
#                 "Tone Dynamics": 6,
#                 "Summary Tone Dynamics": "The tone was serious with some critical exchanges.",
#                 "Power Dynamics": 8,
#                 "Summary Power Dynamics": "Males displayed more power in the interactions, leading to some interruptions.",
#                 "Total score (average of all)": 6.75,
#                 "Total summary": "Male to female interactions showed a slight power imbalance."
#             }
#         },
#         "overall_trends": "The debate showcased a mix of assertive and collaborative interactions, with a notable emphasis on the need for clarity in political language. Male participants tended to dominate discussions, while female participants provided valuable insights that were sometimes overshadowed.",
#         "final_score": 7.25
#     },
#     {
#         "episode_name": "Debatten - 17. okt. \u00b7 Slik kan du spare p\u00e5 maten.nb-ttv",
#         "participants": [
#             {
#                 "role": "Debater 1",
#                 "gender": "F",
#                 "background": "Cookbook author, food writer, and food blogger"
#             },
#             {
#                 "role": "Expert 1",
#                 "gender": "F",
#                 "background": "Senior advisor at SIFO"
#             },
#             {
#                 "role": "Expert 2",
#                 "gender": "F",
#                 "background": "Economist at Storebrand"
#             },
#             {
#                 "role": "Expert 3",
#                 "gender": "M",
#                 "background": "Frugal living expert"
#             },
#             {
#                 "role": "Expert 4",
#                 "gender": "F",
#                 "background": "Consumer economist at Sparebank1"
#             },
#             {
#                 "role": "Debater 2",
#                 "gender": "M",
#                 "background": "Student"
#             },
#             {
#                 "role": "Debater 3",
#                 "gender": "F",
#                 "background": "Single mother and leader of a youth organization"
#             },
#             {
#                 "role": "Debater 4",
#                 "gender": "M",
#                 "background": "Retired actor"
#             },
#             {
#                 "role": "Debater 5",
#                 "gender": "F",
#                 "background": "Influencer and savings expert"
#             },
#             {
#                 "role": "Debater 6",
#                 "gender": "M",
#                 "background": "Influencer and food budget advisor"
#             },
#             {
#                 "role": "Debater 7",
#                 "gender": "F",
#                 "background": "Food influencer"
#             },
#             {
#                 "role": "Debater 8",
#                 "gender": "M",
#                 "background": "Food influencer"
#             }
#         ],
#         "interaction_analysis": {
#             "M_to_M": {
#                 "Argument Strength": 7,
#                 "Summary Argument Strength": "Arguments were generally clear and relevant, but sometimes lacked depth.",
#                 "Engagement Style": 6,
#                 "Summary Engagement Style": "Interactions were assertive but occasionally dismissive.",
#                 "Tone Dynamics": 7,
#                 "Summary Tone Dynamics": "Tone was mostly serious with moments of light-heartedness.",
#                 "Power Dynamics": 5,
#                 "Summary Power Dynamics": "There were instances of interruptions but generally balanced.",
#                 "Total score (average of all)": 6.25,
#                 "Total summary": "Interactions were constructive but could benefit from deeper engagement."
#             },
#             "F_to_F": {
#                 "Argument Strength": 8,
#                 "Summary Argument Strength": "Arguments were well-structured and persuasive, providing solid insights.",
#                 "Engagement Style": 8,
#                 "Summary Engagement Style": "Participants showed empathy and collaboration in their exchanges.",
#                 "Tone Dynamics": 8,
#                 "Summary Tone Dynamics": "Tone was supportive and constructive throughout the discussion.",
#                 "Power Dynamics": 7,
#                 "Summary Power Dynamics": "Interactions were respectful with few interruptions.",
#                 "Total score (average of all)": 7.75,
#                 "Total summary": "Strong collaboration and engagement characterized the interactions."
#             },
#             "F_to_M": {
#                 "Argument Strength": 8,
#                 "Summary Argument Strength": "Arguments were relevant and compelling, often addressing key issues.",
#                 "Engagement Style": 7,
#                 "Summary Engagement Style": "Engagement was assertive, with a mix of support and challenge.",
#                 "Tone Dynamics": 7,
#                 "Summary Tone Dynamics": "Tone varied from critical to supportive, maintaining engagement.",
#                 "Power Dynamics": 6,
#                 "Summary Power Dynamics": "Some power imbalances noted, but generally respectful.",
#                 "Total score (average of all)": 6.75,
#                 "Total summary": "Interactions were effective, balancing assertiveness with support."
#             },
#             "M_to_F": {
#                 "Argument Strength": 7,
#                 "Summary Argument Strength": "Arguments presented were relevant but sometimes lacked depth.",
#                 "Engagement Style": 6,
#                 "Summary Engagement Style": "Engagement was often assertive, with some defensiveness noted.",
#                 "Tone Dynamics": 6,
#                 "Summary Tone Dynamics": "Tone was mostly serious with some moments of lightness.",
#                 "Power Dynamics": 5,
#                 "Summary Power Dynamics": "Power imbalances were present, with some interruptions.",
#                 "Total score (average of all)": 6.0,
#                 "Total summary": "Interactions were constructive but could improve in depth and respect."
#             }
#         },
#         "overall_trends": "The debate showcased a mix of assertiveness and collaboration, with female participants often demonstrating stronger engagement styles and argument strength. Male participants tended to assert their points more forcefully but occasionally lacked the depth seen in female contributions.",
#         "final_score": 7.0
#     },
#     {
#         "episode_name": "Debatten - 8. okt. \u00b7 Tidenes budsjett, men misn\u00f8yen vokser.nb-ttv",
#         "participants": [
#             {
#                 "role": "Debater 1",
#                 "gender": "M",
#                 "background": "Political Editor, Swedish Newspaper"
#             },
#             {
#                 "role": "Expert 1",
#                 "gender": "F",
#                 "background": "Professor, Institute of Social Economics, BI"
#             },
#             {
#                 "role": "Expert 2",
#                 "gender": "M",
#                 "background": "Professor, Social Economics, UIS"
#             },
#             {
#                 "role": "Expert 3",
#                 "gender": "M",
#                 "background": "Professor Emeritus, Economic Institute, UiO"
#             },
#             {
#                 "role": "Expert 4",
#                 "gender": "M",
#                 "background": "Professor of Economic History, UiO"
#             },
#             {
#                 "role": "Expert 5",
#                 "gender": "F",
#                 "background": "Senior Researcher, Public Health Institute and UiO"
#             },
#             {
#                 "role": "Debater 2",
#                 "gender": "F",
#                 "background": "Former Finance Minister, Political Party"
#             },
#             {
#                 "role": "Debater 3",
#                 "gender": "M",
#                 "background": "Current Auditor General, Former Finance Minister"
#             }
#         ],
#         "interaction_analysis": {
#             "M_to_M": {
#                 "Argument Strength": 7,
#                 "Summary Argument Strength": "Both male debaters presented strong arguments regarding budget allocations and the implications of oil wealth.",
#                 "Engagement Style": 6,
#                 "Summary Engagement Style": "Engagement was generally assertive, with some instances of defensiveness.",
#                 "Tone Dynamics": 5,
#                 "Summary Tone Dynamics": "Tone varied from critical to somewhat supportive, but overall remained serious.",
#                 "Power Dynamics": 6,
#                 "Summary Power Dynamics": "There were moments of interruption, but overall a balanced exchange.",
#                 "Total score (average of all)": 6.5,
#                 "Total summary": "The interaction between male debaters was assertive, with a good balance of power."
#             },
#             "F_to_F": {
#                 "Argument Strength": 8,
#                 "Summary Argument Strength": "The female experts provided insightful perspectives on the implications of oil wealth and social issues.",
#                 "Engagement Style": 7,
#                 "Summary Engagement Style": "Engagement was collaborative, with a focus on building upon each other's points.",
#                 "Tone Dynamics": 6,
#                 "Summary Tone Dynamics": "Tone was supportive, with constructive criticism.",
#                 "Power Dynamics": 5,
#                 "Summary Power Dynamics": "There was a respectful exchange without significant power imbalances.",
#                 "Total score (average of all)": 6.5,
#                 "Total summary": "The interaction between female experts was collaborative and insightful."
#             },
#             "F_to_M": {
#                 "Argument Strength": 9,
#                 "Summary Argument Strength": "Female participants effectively challenged male perspectives on budget allocations and social implications.",
#                 "Engagement Style": 8,
#                 "Summary Engagement Style": "Highly engaging with a focus on challenging and refining arguments.",
#                 "Tone Dynamics": 7,
#                 "Summary Tone Dynamics": "Tone was assertive and at times confrontational, but remained respectful.",
#                 "Power Dynamics": 6,
#                 "Summary Power Dynamics": "Female participants held their ground well against male counterparts.",
#                 "Total score (average of all)": 7.5,
#                 "Total summary": "The interaction between female and male participants was dynamic and engaging."
#             },
#             "M_to_F": {
#                 "Argument Strength": 7,
#                 "Summary Argument Strength": "Male participants presented strong arguments but were occasionally dismissive of female perspectives.",
#                 "Engagement Style": 5,
#                 "Summary Engagement Style": "Engagement was somewhat uneven, with moments of defensiveness from male participants.",
#                 "Tone Dynamics": 6,
#                 "Summary Tone Dynamics": "Tone was serious, with some condescending undertones.",
#                 "Power Dynamics": 7,
#                 "Summary Power Dynamics": "Males dominated the conversation, leading to occasional interruptions.",
#                 "Total score (average of all)": 6.25,
#                 "Total summary": "The interaction was marked by a power imbalance favoring male participants."
#             }
#         },
#         "overall_trends": "The debate showcased a mix of strong arguments from both genders, with female participants often challenging male perspectives effectively. The interactions highlighted some power imbalances, particularly in male-to-female exchanges.",
#         "final_score": 6.5
#     }
# ]

# %% [markdown]
# ##Make to DF

# %%
import pandas as pd

# Assuming final_json_result is already loaded
# final_json_result = json.loads(json_string)

# Create scores_data DataFrame
scores_data = []
for episode in final_json_result:
    episode_name = episode['episode_name']
    for interaction, details in episode["interaction_analysis"].items():
        scores_data.append({
            "episode_name": episode_name,
            "interaction_type": interaction,
            "argument_strength": details.get("Argument Strength", details.get("Argument Strenght", 0)),
            "summary_argument_strength": details.get("Summary Argument Strength", details.get("Summary Argument Strenght", "")),
            "engagement_style": details.get("Engagement Style", 0),
            "summary_engagement_style": details.get("Summary Engagement Style", details.get("Summary Engagement style", "")),
            "tone_dynamics": details.get("Tone Dynamics", 0),
            "summary_tone_dynamics": details.get("Summary Tone Dynamics", ""),
            "power_dynamics": details.get("Power Dynamics", 0),
            "summary_power_dynamics": details.get("Summary Power Dynamics", ""),
            "total_score": details.get("Total score (average of all)", 0),
            "total_summary": details.get("Total summary", "")
        })

scores_df = pd.DataFrame(scores_data)

# Create participants_data DataFrame
participants_data = []
for episode in final_json_result:
    episode_name = episode['episode_name']
    for participant in episode.get("participants", []):
        participants_data.append({
            "episode_name": episode_name,
            "role": participant.get("role", ""),
            "gender": participant.get("gender", ""),
            "background": participant.get("background", "")
        })

participants_df = pd.DataFrame(participants_data)

# Display the DataFrames
print("Scores DataFrame:")
print(scores_df)
print("\nParticipants DataFrame:")
print(participants_df)
# Out:
# Scores DataFrame:
#                                          episode_name interaction_type  \
# 0   Debatten - 10. okt. · Bløffebudsjett, mener op...           M_to_M
# 1   Debatten - 10. okt. · Bløffebudsjett, mener op...           F_to_F
# 2   Debatten - 10. okt. · Bløffebudsjett, mener op...           F_to_M
# 3   Debatten - 10. okt. · Bløffebudsjett, mener op...           M_to_F
# 4   Debatten - 22. okt. · Milliardene flyr i havvi...           M_to_M
# 5   Debatten - 22. okt. · Milliardene flyr i havvi...           F_to_F
# 6   Debatten - 22. okt. · Milliardene flyr i havvi...           F_to_M
# 7   Debatten - 22. okt. · Milliardene flyr i havvi...           M_to_F
# 8   Debatten - 15. okt. · Skoler legges ned, bygde...           M_to_M
# 9   Debatten - 15. okt. · Skoler legges ned, bygde...           F_to_F
# 10  Debatten - 15. okt. · Skoler legges ned, bygde...           F_to_M
# 11  Debatten - 15. okt. · Skoler legges ned, bygde...           M_to_F
# 12          Debatten - Torsdag · «Falsk same»？.nb-ttv           M_to_M
# 13          Debatten - Torsdag · «Falsk same»？.nb-ttv           F_to_F
# 14          Debatten - Torsdag · «Falsk same»？.nb-ttv           F_to_M
# 15          Debatten - Torsdag · «Falsk same»？.nb-ttv           M_to_F
# 16          Debatten - 29. okt. · Du blir lurt.nb-ttv           M_to_M
# 17          Debatten - 29. okt. · Du blir lurt.nb-ttv           F_to_F
# 18          Debatten - 29. okt. · Du blir lurt.nb-ttv           F_to_M
# 19          Debatten - 29. okt. · Du blir lurt.nb-ttv           M_to_F
# 20  Debatten - 24. okt. · Unge sender Ap mot sperr...           M_to_M
# 21  Debatten - 24. okt. · Unge sender Ap mot sperr...           F_to_F
# 22  Debatten - 24. okt. · Unge sender Ap mot sperr...           F_to_M
# 23  Debatten - 24. okt. · Unge sender Ap mot sperr...           M_to_F
# 24  Debatten - 31. okt. · Milliarder til norske ba...           M_to_M
# 25  Debatten - 31. okt. · Milliarder til norske ba...           F_to_F
# 26  Debatten - 31. okt. · Milliarder til norske ba...           F_to_M
# 27  Debatten - 31. okt. · Milliarder til norske ba...           M_to_F
# 28  Debatten - 17. okt. · Slik kan du spare på mat...           M_to_M
# 29  Debatten - 17. okt. · Slik kan du spare på mat...           F_to_F
# 30  Debatten - 17. okt. · Slik kan du spare på mat...           F_to_M
# 31  Debatten - 17. okt. · Slik kan du spare på mat...           M_to_F
# 32  Debatten - 8. okt. · Tidenes budsjett, men mis...           M_to_M
# 33  Debatten - 8. okt. · Tidenes budsjett, men mis...           F_to_F
# 34  Debatten - 8. okt. · Tidenes budsjett, men mis...           F_to_M
# 35  Debatten - 8. okt. · Tidenes budsjett, men mis...           M_to_F
#
#     argument_strength                          summary_argument_strength  \
# 0                   7  Both male debaters presented clear and relevan...
# 1                   8  Female debaters articulated strong arguments, ...
# 2                   9  Female debaters provided compelling counterarg...
# 3                   7  Male debaters presented their arguments clearl...
# 4                   7  Participants presented strong, data-driven arg...
# 5                   8  The arguments presented were well-structured a...
# 6                   6  Arguments were relevant but sometimes lacked d...
# 7                   7  Arguments were well-articulated but occasional...
# 8                   7  Both male participants presented strong argume...
# 9                   8  The female participants articulated their conc...
# 10                  8  Female participants presented compelling argum...
# 11                  7  Male arguments were generally strong but occas...
# 12                  7  Both male participants presented their argumen...
# 13                  8  Female participants articulated their views st...
# 14                  7  Female participants presented compelling argum...
# 15                  6  Male participants provided relevant arguments,...
# 16                  8  Both male participants presented strong, relev...
# 17                  9  The female participants effectively articulate...
# 18                  8  Female participants brought valuable perspecti...
# 19                  7  Male arguments were mostly strong but occasion...
# 20                  8  Both debaters presented strong arguments, with...
# 21                  0  No female participants engaged in direct dialo...
# 22                  0  No female participants engaged with male parti...
# 23                  0  No male participants engaged with female parti...
# 24                  7  Participants present clear, relevant arguments...
# 25                  8  Strong arguments with clear articulation of po...
# 26                  8  Female participants present compelling argumen...
# 27                  7  Male participants provide relevant arguments b...
# 28                  7  Arguments were relevant but at times lacked de...
# 29                  8               Arguments were clear and persuasive.
# 30                  8     Arguments were compelling and well-structured.
# 31                  6          Arguments were relevant but lacked depth.
# 32                  8  Both male debaters presented strong arguments ...
# 33                  9  The female debaters presented compelling argum...
# 34                  8  The female debater effectively challenged the ...
# 35                  8  The male debater acknowledged the points made ...
#
#     engagement_style                           summary_engagement_style  \
# 0                  6  Interactions were assertive, with some defensi...
# 1                  8  Interactions were empathetic and constructive,...
# 2                  8  Interactions were assertive yet respectful, wi...
# 3                  7  Interactions were competitive, with males ofte...
# 4                  6  Engagement was generally assertive, with some ...
# 5                  7       Engagement was collaborative and respectful.
# 6                  5  Engagement was generally polite but somewhat h...
# 7                  6  Engagement was assertive, with some attempts a...
# 8                  6  Engagement was assertive but sometimes defensi...
# 9                  9  High engagement with empathy and support for e...
# 10                 7  Engagement was assertive, with females pushing...
# 11                 5  Engagement was mixed; assertive but at times c...
# 12                 6  Interactions were assertive but occasionally d...
# 13                 7  Engagement was empathetic and collaborative, a...
# 14                 6  Engagement was assertive, with some defensiven...
# 15                 5  Engagement was somewhat defensive, particularl...
# 16                 7  Interactions were assertive, with a focus on p...
# 17                 8  Empathetic and supportive, fostering a collabo...
# 18                 8  Engaging and assertive, with a focus on collab...
# 19                 6  Assertive, but at times dismissive of female c...
# 20                 7  Engagement was assertive, with both participan...
# 21                 0  No female participants engaged in direct dialo...
# 22                 0  No female participants engaged with male parti...
# 23                 0  No male participants engaged with female parti...
# 24                 6  Interactions are assertive with some moments o...
# 25                 7         Supportive and collaborative interactions.
# 26                 7   Engagement is assertive with a focus on clarity.
# 27                 6  Interactions are often assertive, sometimes di...
# 28                 6             Assertive but occasionally dismissive.
# 29                 9                      Empathetic and collaborative.
# 30                 7                          Assertive yet respectful.
# 31                 5                Assertive but sometimes dismissive.
# 32                 7  Engagement was assertive, with both showing a ...
# 33                 8  Engagement was collaborative, with both suppor...
# 34                 8  Engagement was assertive, with the female deba...
# 35                 7  Engagement was respectful, with the male debat...
#
#     tone_dynamics                              summary_tone_dynamics  \
# 0               6  Tone varied from critical to slightly supporti...
# 1               8  Tone was generally supportive, with moments of...
# 2               7  Tone was assertive and at times critical, but ...
# 3               6  Tone was somewhat critical, with males dominat...
# 4               7  The tone was mostly serious and analytical, wi...
# 5               6  Tone was supportive but occasionally confronta...
# 6               6  Tone varied, with moments of frustration evident.
# 7               7  Tone was mostly respectful, with some critical...
# 8               5  Tone varied from serious to confrontational, e...
# 9               8  Supportive and passionate tone, emphasizing co...
# 10              7  Tone was assertive yet respectful, maintaining...
# 11              6  Tone ranged from supportive to dismissive, par...
# 12              6  Tone varied between critical and supportive, w...
# 13              7  Tone was mostly supportive, with some critical...
# 14              5  Tone ranged from supportive to confrontational...
# 15              6  Tone was mostly neutral, with moments of tensi...
# 16              6  The tone was serious and focused, with moments...
# 17              8  Supportive and concerned, highlighting the hum...
# 18              7  Tone was assertive yet respectful, with a focu...
# 19              6  Tone varied, with some critical moments oversh...
# 20              6  The tone varied between critical and assertive...
# 21              0  No female participants engaged in direct dialo...
# 22              0  No female participants engaged with male parti...
# 23              0  No male participants engaged with female parti...
# 24              6   Tone is mostly serious, with occasional sarcasm.
# 25              7               Tone is constructive and respectful.
# 26              6        Tone is serious, sometimes confrontational.
# 27              5                Tone can be condescending at times.
# 28              7  Generally supportive but with some critical un...
# 29              8                       Supportive and constructive.
# 30              8      Generally positive with some critical points.
# 31              6                Mixed tones, occasionally critical.
# 32              6  Tone was generally serious, with moments of hu...
# 33              7  Tone was constructive, with a focus on solutio...
# 34              7  Tone was assertive yet respectful, with moment...
# 35              6  Tone was generally positive, with encouragemen...
#
#     power_dynamics                             summary_power_dynamics  \
# 0                7  There were instances of interruptions, but ove...
# 1                6  There was a moderate level of power dynamics a...
# 2                8  Female debaters effectively held their ground ...
# 3                7  There were noticeable power imbalances, with m...
# 4                5  Power dynamics were relatively balanced, thoug...
# 5                5  Power dynamics were equal, with both participa...
# 6                4  Power imbalances were noticeable, with some ma...
# 7                5  Power dynamics were mixed, with males occasion...
# 8                6  There were moments of power imbalance with int...
# 9                7  Balanced power dynamics with mutual respect an...
# 10               6  Some power dynamics shifted as females effecti...
# 11               5  Males often dominated the conversation, leadin...
# 12               5  Power dynamics were relatively balanced, altho...
# 13               6  There was a good balance of speaking time, wit...
# 14               5  The dynamics were somewhat imbalanced, with ma...
# 15               6  Males displayed more power through interruptio...
# 16               7  There was a balanced exchange, though some int...
# 17               6  Interactions were respectful, with a few momen...
# 18               7  Generally balanced, though some male speakers ...
# 19               8  Male participants tended to dominate discussio...
# 20               5  There was a moderate level of power dynamics, ...
# 21               0  No female participants engaged in direct dialo...
# 22               0  No female participants engaged with male parti...
# 23               0  No male participants engaged with female parti...
# 24               7  Some interruptions and attempts to dominate th...
# 25               5          Less power struggle, more mutual respect.
# 26               6  Some instances of power imbalance with males d...
# 27               7  Males often dominate discussions, which impact...
# 28               5  Equal participation but some interruptions noted.
# 29               7                      Balanced with mutual respect.
# 30               6     Males occasionally dominated the conversation.
# 31               7            Males occasionally interrupted females.
# 32               7  Interactions showed a balance of power, with n...
# 33               6  Interactions showed equality, with both female...
# 34               7  The female debater exhibited strong presence, ...
# 35               6  The male debater maintained a supportive role,...
#
#     total_score                                      total_summary
# 0          6.50  The male debaters engaged in a competitive deb...
# 1          7.50  The female debaters showed strong engagement a...
# 2          8.00  The female to male interactions were strong, w...
# 3          6.75  The male to female dynamics displayed some pow...
# 4          6.25  Overall, the M to M interactions were construc...
# 5          6.25  F to F interactions were effective, showcasing...
# 6          5.25  F to M interactions showed some challenges, pa...
# 7          6.25  M to F interactions were generally positive bu...
# 8          6.00  Overall, male interactions were assertive but ...
# 9          8.00  Female interactions were collaborative and emp...
# 10         7.00  Interactions were strong, with females effecti...
# 11         5.75  Male to female interactions were often dominat...
# 12         6.00  Overall, male participants engaged in a constr...
# 13         7.00  Female participants demonstrated strong engage...
# 14         6.00  Female participants effectively challenged mal...
# 15         5.75  Male participants maintained a degree of autho...
# 16         7.00  Overall, the male-to-male interactions were co...
# 17         7.75  Female interactions emphasized emotional intel...
# 18         7.75  Interactions were effective, with a good balan...
# 19         6.75  While informative, the male-to-female interact...
# 20         6.50  The interactions between the male debaters wer...
# 21         0.00  No interactions were recorded between female p...
# 22         0.00  No interactions were recorded between female a...
# 23         0.00  No interactions were recorded between male and...
# 24         6.40  Overall, the male participants engage actively...
# 25         6.60  Female participants demonstrate effective comm...
# 26         6.80  Female participants effectively engage with ma...
# 27         6.30  Male participants need to improve their respon...
# 28         6.25  Males engaged in a balanced discussion, though...
# 29         8.14  Females demonstrated strong collaboration and ...
# 30         7.25  Females presented strong arguments but faced s...
# 31         6.00  Males engaged but demonstrated some dismissive...
# 32         7.50  The interaction between male debaters was char...
# 33         7.50  The interaction between female debaters was st...
# 34         7.50  The interaction between female and male debate...
# 35         6.75  The interaction between male and female debate...
#
# Participants DataFrame:
#                                          episode_name       role gender  \
# 0   Debatten - 10. okt. · Bløffebudsjett, mener op...  debater 1      M
# 1   Debatten - 10. okt. · Bløffebudsjett, mener op...  debater 2      F
# 2   Debatten - 10. okt. · Bløffebudsjett, mener op...  debater 3      F
# 3   Debatten - 10. okt. · Bløffebudsjett, mener op...  debater 4      M
# 4   Debatten - 10. okt. · Bløffebudsjett, mener op...  debater 5      F
# ..                                                ...        ...    ...
# 76  Debatten - 8. okt. · Tidenes budsjett, men mis...  Debater 4      M
# 77  Debatten - 8. okt. · Tidenes budsjett, men mis...  Debater 5      F
# 78  Debatten - 8. okt. · Tidenes budsjett, men mis...  Debater 6      M
# 79  Debatten - 8. okt. · Tidenes budsjett, men mis...  Debater 7      F
# 80  Debatten - 8. okt. · Tidenes budsjett, men mis...  Debater 8      M
#
#                                            background
# 0            Leader of the Conservative Party (Høyre)
# 1                     Leader of the Labour Party (Ap)
# 2             Leader of the Socialist Left Party (SV)
# 3                  Leader of the Progress Party (FrP)
# 4                     Leader of the Centre Party (Sp)
# ..                                                ...
# 76                 Professor of Economic History, UiO
# 77  Senior researcher, Norwegian Institute of Publ...
# 78           Former finance minister, political party
# 79           Former finance minister, political party
# 80                                 Former riksrevisor
#
# [81 rows x 4 columns]

# %% [markdown]
# ##Save as xlsx

# %%
# Save the DataFrames as separate Excel files in /content/ directory
scores_output_path = '/content/scores_analysis_results.xlsx'
participants_output_path = '/content/participants_analysis_results.xlsx'

# Save each DataFrame to an Excel file
scores_df.to_excel(scores_output_path, index=False)
participants_df.to_excel(participants_output_path, index=False)

(scores_output_path, participants_output_path)
# Out:
# ('/content/scores_analysis_results.xlsx',
#  '/content/participants_analysis_results.xlsx')

# %%
import pandas as pd
import json

# Assuming final_json_result is already loaded
# final_json_result = json.loads(json_string)

# Create scores_data DataFrame
scores_data = []
for episode in final_json_result:
    episode_name = episode['episode_name']
    for interaction_type, details in episode["interaction_analysis"].items():
        scores_data.append({
            "episode_name": episode_name,
            "interaction_type": interaction_type,
            "Argument Strength": details.get("Argument Strength", details.get("Argument Strenght", 0)),
            "Engagement Style": details.get("Engagement Style", 0),
            "Tone Dynamics": details.get("Tone Dynamics", 0),
            "Power Dynamics": details.get("Power Dynamics", 0),
            "Total Score": details.get("Total score (average of all)", 0)
        })

scores_df = pd.DataFrame(scores_data)

# Group by interaction_type and calculate average scores
average_scores = scores_df.groupby('interaction_type').agg({
    'Argument Strength': 'mean',
    'Engagement Style': 'mean',
    'Tone Dynamics': 'mean',
    'Power Dynamics': 'mean',
    'Total Score': 'mean'
}).round(2)  # Round to 2 decimal places for readability

# Calculate overall average across all interaction types
overall_average = average_scores.mean().round(2)
overall_average.name = 'Overall Average'

# Add overall average to the results using concat instead of append
final_results = pd.concat([average_scores, overall_average.to_frame().T])

print("Average Scores by Interaction Type:")
print(final_results)

# Optionally, you can save this to a CSV file
final_results.to_csv('average_scores_by_interaction.csv')
# Out:
# Average Scores by Interaction Type:
#                  Argument Strength  Engagement Style  Tone Dynamics  \
# F_to_F                        7.33              7.00           6.56
# F_to_M                        6.89              6.22           5.89
# M_to_F                        6.11              5.22           5.33
# M_to_M                        7.33              6.33           6.11
# Overall Average               6.91              6.19           5.97
#
#                  Power Dynamics  Total Score
# F_to_F                     5.33         6.53
# F_to_M                     5.44         6.17
# M_to_F                     5.67         5.59
# M_to_M                     6.00         6.49
# Overall Average            5.61         6.20
