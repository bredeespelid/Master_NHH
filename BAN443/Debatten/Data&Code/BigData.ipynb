# %% [markdown]
# #Set up the API

# %%
# Installing the required packages
# %pip install -U openai pydantic

# %%
# Set environment variables and create openai client

import os
from openai import AzureOpenAI
from google.colab import userdata # To get the secret keys

# Deployment name in azure openai studio
gpt_model = "gpt-4o-mini"  # ex. gpt-4o-mini

client = AzureOpenAI(
    api_key=userdata.get('AZURE_OPENAI_API_KEY'),
    api_version="2023-03-15-preview",
    azure_endpoint=userdata.get('AZURE_OPENAI_ENDPOINT'),
)

# %%
# Test that everything is working
messages = [{"role": "user", "content": "Hello, ready for some AI analysis?"}]
response = client.chat.completions.create(model=gpt_model, messages=messages, max_tokens=50)

print("Response: \n", response.choices[0].message.content)

# Expected respnse should be something like:
# Response:
#  Absolutely! What do you need analyzed?

# %% [markdown]
# #Food-debate

# %%
import json
from openai.types.chat import ChatCompletionUserMessageParam, ChatCompletionSystemMessageParam

path_to_file = "Test.txt"

# Read the data from the file
with open(path_to_file, "r", encoding="UTF-8") as file:
    data = file.read()

messages = [
    ChatCompletionSystemMessageParam(
        role="system",
        content="""
            You are an expert in language analysis and interaction analysis in discussions, with a focus on identifying all unique speakers in dialogue.
Your task is to analyze the entire text provided and:

1. Identify and label each unique speaker based on their speech patterns, contextual cues, or dialogue markers.
2. Assign a unique identifier to each speaker (e.g., "Speaker 1," "Speaker 2," etc.) and determine their gender (M/F) when possible based on context.
3. Include all participants present in the text and ensure no speaker is omitted. Do not limit the identification to a predefined number of examples.
4. Look for shifts in tone, specific language usage, or structural cues in the dialogue to differentiate speakers.
3. Examine Interaction Styles:
            - Detailed Tone Categorization: Break down the tone analysis into subcategories, such as empathetic, argumentative, defensive, or conciliatory, to gain a more comprehensive understanding of the interaction style.
            - Emotion Detection: Incorporate sentiment analysis tools to detect emotions like frustration, enthusiasm, or sarcasm. This helps capture subtle nuances in interactions that extend beyond simple supportive or critical categories.
            - Power Dynamics: Analyze indications of power imbalances, such as frequent interruptions, speaking over others, or dismissive responses.
4. Use an analysis model: Analyze how gender patterns may influence treatment in interactions, while controlling for other variables.

Analyze the interactions between all participants and categorize them into gender-based combinations (M to M, F to M, F to F, M to F). Ensure the output is presented in JSON format as follows:
{
    "episode_name": "<generated_name>",
    "participants": [
        {
            "role": "<role>",
            "gender": "<M/F>",
            "background": "(party affiliation, organization, etc.)"
        }
    ],
    "interaction_analysis": {
        "M_to_M": {
            "summary": "<summary>",
            "score": <number>
        },
        "F_to_F": {
            "summary": "<summary>",
            "score": <number>
        },
        "F_to_M": {
            "summary": "<summary>",
            "score": <number>
        },
        "M_to_F": {
            "summary": "<summary>",
            "score": <number>
        }
    },
    "overall_trends": "<description>",
    "final_score": <number>
}
""",
    ),
    ChatCompletionUserMessageParam(
        role="user",
        content=f"""
            Analyze the text below and categorize participants as “debater 1,” “debater 2,” “expert 1,” etc.
            Evaluate how they interact with each other in all gender combinations (M to M, F to M, F to F, M to F).
            Include all participants and do not include the moderator in the analysis.
            In English only.

            <data>{data}</data>

        Response:
        """,
    ),
]

completion = client.chat.completions.create(
    model="gpt-4o-mini",  # Replace with your actual model name
    messages=messages,
    temperature=0,
    response_format={"type": "json_object"},  # Guarantees that the response is in JSON format
)

assert completion.choices[0].message.content is not None

# Print and parse the JSON response
print(completion.choices[0].message.content)

analysis_result = json.loads(completion.choices[0].message.content)
print("Overall score for analysis:", analysis_result["final_score"])

# %% [markdown]
# #Political Debate

# %%
import json
from openai.types.chat import ChatCompletionUserMessageParam, ChatCompletionSystemMessageParam

path_to_file = "Test.vtt"

# Read the data from the file
with open(path_to_file, "r", encoding="UTF-8") as file:
    data = file.read()

messages = [
    ChatCompletionSystemMessageParam(
        role="system",
        content="""
            You are an expert in language analysis and interaction analysis in discussions, with a focus on identifying all unique speakers in dialogue.
Your task is to analyze the entire text provided and:

1. Identify and label each unique speaker based on their speech patterns, contextual cues, or dialogue markers.
2. Assign a unique identifier to each speaker (e.g., "Speaker 1," "Speaker 2," etc.) and determine their gender (M/F) when possible based on context.
3. Include all participants present in the text and ensure no speaker is omitted. Do not limit the identification to a predefined number of examples.
4. Look for shifts in tone, specific language usage, or structural cues in the dialogue to differentiate speakers.
5. Comprehensive Interaction Analysis: Evaluate and score the interactions between all debaters, not just a sample. This analysis should include every interaction and response in the provided text to ensure an accurate and holistic assessment of how each participant interacts with others.
  Scoring Categories:
    -Argument Strength: Rate the clarity, relevance, and persuasiveness of each participant’s arguments throughout the discussion.
    -Engagement Style: Assess interaction qualities such as empathy, assertiveness, defensiveness, or conciliation as demonstrated across all dialogue.
    -Tone Dynamics: Identify variations in tone such as supportive, critical, sarcastic, or enthusiastic exchanges, considering the entire range of interactions.
    -Power Dynamics: Score power displays or imbalances, such as interruptions, speaking over others, or dismissive responses, over the entire debate.
6. Use an analysis model: Analyze how gender patterns may influence treatment in interactions, while controlling for other variables.
7. Final Scoring: Combine scores across all categories for each participant to assign a final score reflecting their overall performance and engagement style in the full debate.

Analyze the interactions between all participants and categorize them into gender-based combinations (M to M, F to M, F to F, M to F). Ensure the output is presented in JSON format as follows:
{
    "episode_name": "<generated_name>",
    "participants": [
        {
            "role": "<role>",
            "gender": "<M/F>",
            "background": "(party affiliation, organization, etc.)"
        }
    ],
    "interaction_analysis": {
        "M_to_M": {
            "summary": "<summary>",
            "score": <number>
        },
        "F_to_F": {
            "summary": "<summary>",
            "score": <number>
        },
        "F_to_M": {
            "summary": "<summary>",
            "score": <number>
        },
        "M_to_F": {
            "summary": "<summary>",
            "score": <number>
        }
    },
    "overall_trends": "<description>",
    "final_score": <number>
}
""",
    ),
    ChatCompletionUserMessageParam(
        role="user",
        content=f"""
            Analyze the text below and categorize participants as “debater 1,” “debater 2,” “expert 1,” etc not their real name.
            Evaluate how they interact with each other in all gender combinations (M to M, F to M, F to F, M to F).
            Include all participants and do not include the moderator in the analysis.
            In English only.

            <data>{data}</data>

        Response:
        """,
    ),
]

completion = client.chat.completions.create(
    model="gpt-4o-mini",  # Replace with your actual model name
    messages=messages,
    temperature=0.5,
    response_format={"type": "json_object"},  # Guarantees that the response is in JSON format
)

assert completion.choices[0].message.content is not None

# Print and parse the JSON response
print(completion.choices[0].message.content)

analysis_result = json.loads(completion.choices[0].message.content)
print("Overall score for analysis:", analysis_result["final_score"])
# Out:
# {
#     "episode_name": "Norwegian Political Debate Analysis",
#     "participants": [
#         {
#             "role": "Debater 1",
#             "gender": "M",
#             "background": "Leader of the Conservative Party"
#         },
#         {
#             "role": "Debater 2",
#             "gender": "F",
#             "background": "Leader of the Labour Party"
#         },
#         {
#             "role": "Debater 3",
#             "gender": "F",
#             "background": "Leader of the Socialist Left Party"
#         },
#         {
#             "role": "Debater 4",
#             "gender": "M",
#             "background": "Leader of the Progress Party"
#         },
#         {
#             "role": "Debater 5",
#             "gender": "F",
#             "background": "Leader of the Centre Party"
#         },
#         {
#             "role": "Debater 6",
#             "gender": "F",
#             "background": "Leader of the Christian Democratic Party"
#         }
#     ],
#     "interaction_analysis": {
#         "M_to_M": {
#             "summary": "Interactions between male debaters often involved assertive exchanges, with interruptions and competitive rhetoric, reflecting a power struggle.",
#             "score": 5
#         },
#         "F_to_F": {
#             "summary": "Female debaters displayed a collaborative tone, showing empathy and support towards each other's arguments, though they also challenged each other respectfully.",
#             "score": 7
#         },
#         "F_to_M": {
#             "summary": "Female debaters engaged assertively with male counterparts, often presenting counterarguments effectively while maintaining a respectful tone.",
#             "score": 6
#         },
#         "M_to_F": {
#             "summary": "Male debaters tended to dominate the conversation, occasionally interrupting female speakers, which created a slight power imbalance.",
#             "score": 4
#         }
#     },
#     "overall_trends": "The debate showcased a mix of competitive and collaborative dynamics, with male debaters often asserting dominance, while female debaters employed empathy and assertiveness in their responses. Gender dynamics were evident, influencing how arguments were presented and received.",
#     "final_score": 6
# }
# Overall score for analysis: 6

# %%
# Konverter interaction_analysis til en DataFrame og legg til episode-navn
df_interaction_analysis = pd.DataFrame.from_dict(analysis_result["interaction_analysis"], orient='index').reset_index()
df_interaction_analysis.columns = ['interaction_type', 'summary', 'score']
df_interaction_analysis['episode_name'] = analysis_result["episode_name"]

# Vis DataFrame
df_interaction_analysis
# Out:
#   interaction_type                                            summary  score  \
# 0           M_to_M  Interactions between male participants were ge...      7
# 1           F_to_F  Female participants engaged in collaborative d...      8
# 2           F_to_M  Female participants often led discussions, wit...      6
# 3           M_to_F  Male participants showed respect and attentive...      7
#
#                      episode_name
# 0  Debatten on Rising Food Prices
# 1  Debatten on Rising Food Prices
# 2  Debatten on Rising Food Prices
# 3  Debatten on Rising Food Prices

# %%
# Lag en matrise med poeng for interaksjoner der radene og kolonnene representerer kjønn (M og F)
gender_matrix = pd.DataFrame(index=["M", "F"], columns=["M", "F"])

# Fyll ut matrisen basert på interaksjonstype i DataFrame
for _, row in df_interaction_analysis.iterrows():
    if row['interaction_type'] == "M_to_M":
        gender_matrix.at["M", "M"] = row['score']
    elif row['interaction_type'] == "F_to_F":
        gender_matrix.at["F", "F"] = row['score']
    elif row['interaction_type'] == "F_to_M":
        gender_matrix.at["F", "M"] = row['score']
    elif row['interaction_type'] == "M_to_F":
        gender_matrix.at["M", "F"] = row['score']

# Vis matrisen
gender_matrix
# Out:
#    M  F
# M  7  7
# F  6  8

# %% [markdown]
# #Bigdata

# %%
import requests
import yt_dlp
import os

# Base URL for NRK's API
base_url = "https://psapi.nrk.no"
series_url = f"{base_url}/tv/catalog/series/debatten"

# Antall episoder vi ønsker å hente, justert for å ignorere første
target_episodes = 9
episodes_needed = target_episodes + 1  # Hent 10 episoder, men ignorer den første
episodes_fetched = 0
page = 1

try:
    all_episodes = []

    # Hent episoder fra API-et
    while len(all_episodes) < episodes_needed:
        response = requests.get(series_url, params={"page": page})
        response.raise_for_status()
        series_data = response.json()

        if '_embedded' in series_data and 'instalments' in series_data['_embedded']:
            instalment_data = series_data['_embedded']['instalments']
            if '_embedded' in instalment_data and 'instalments' in instalment_data['_embedded']:
                episodes = instalment_data['_embedded']['instalments']
                all_episodes.extend(episodes)

                # Sjekk om det er flere sider
                if '_links' in instalment_data and 'next' in instalment_data['_links']:
                    page += 1
                else:
                    break  # Ingen flere sider
            else:
                break  # Ingen flere episoder funnet
        else:
            break  # Ingen flere episoder funnet

    # Fjern den første episoden og samle URL-ene for resten
    all_episodes = all_episodes[1:episodes_needed]  # Ignorer den første episoden

    # Samle URL-ene i en liste kalt URL
    URL = [f'https://tv.nrk.no/se?v={episode["prfId"]}' for episode in all_episodes]

    # Print en melding som viser hvor mange episoder som er hentet
    print(f"Episodes of Debatten (totalt {len(URL)}):")

    # Funksjon for å laste ned undertekster
    def download_subtitles(url, download_path):
        ydl_opts = {
            'writesubtitles': True,
            'subtitleslangs': ['nb-ttv'],  # Norsk bokmål TV-teksting
            'skip_download': True,  # Hopp over nedlasting av video
            'outtmpl': os.path.join(download_path, '%(title)s.%(ext)s'),
            'quiet': True,  # Reduserer mengden output til et minimum
            'no_warnings': True,  # Skjuler advarsler
            'postprocessors': [{
                'key': 'FFmpegSubtitlesConvertor',
                'format': 'srt',
            }],
            'logger': None,  # Fjerner logger-objektet for mindre støy
        }

        try:
            with yt_dlp.YoutubeDL(ydl_opts) as ydl:
                ydl.download([url])
            print(f"Subtitles downloaded for URL: {url}")
            return True  # Returner True hvis nedlasting var vellykket
        except Exception as e:
            print(f"En feil oppstod for {url}: {e}")
            return False  # Returner False hvis det oppstod en feil

    # Opprett mappe for lagring av undertekster
    download_path = os.path.join(os.getcwd(), "Debatten_subtitles")
    os.makedirs(download_path, exist_ok=True)

    # Last ned undertekster for hver URL i listen
    valid_urls = []
    for i, url in enumerate(URL):
        success = download_subtitles(url, download_path)
        if not success:
            print("Prøver neste tilgjengelige episode...")
            continue  # Gå videre til neste episode
        valid_urls.append(url)

    if len(valid_urls) < target_episodes:
        print(f"Kun {len(valid_urls)} episoder ble lastet ned vellykket.")
    else:
        print("All episodes fetched sucsessfully.")

except requests.RequestException as e:
    print(f"En feil oppstod ved henting av data: {e}")
# Out:
# Episodes of Debatten (totalt 9):
# Subtitles downloaded for URL: https://tv.nrk.no/se?v=NNFA51103124
# Subtitles downloaded for URL: https://tv.nrk.no/se?v=NNFA51102924
# Subtitles downloaded for URL: https://tv.nrk.no/se?v=NNFA51102424
# Subtitles downloaded for URL: https://tv.nrk.no/se?v=NNFA51102224
# Subtitles downloaded for URL: https://tv.nrk.no/se?v=NNFA51101724
# Subtitles downloaded for URL: https://tv.nrk.no/se?v=NNFA51101524
# Subtitles downloaded for URL: https://tv.nrk.no/se?v=NNFA51101024
# Subtitles downloaded for URL: https://tv.nrk.no/se?v=NNFA51100824
# Subtitles downloaded for URL: https://tv.nrk.no/se?v=NNFA51100324
# All episodes fetched sucsessfully.

# %%
import os
import json
import openai


# Katalog som inneholder VTT-filer
directory_path = "Debatten_subtitles"

# Liste for å lagre analyseresultater for alle filer
analysis_results = []

# Iterer gjennom alle VTT-filer i katalogen
for filename in os.listdir(directory_path):
    if filename.endswith(".vtt"):
        file_path = os.path.join(directory_path, filename)

        # Les data fra VTT-filen
        with open(file_path, "r", encoding="UTF-8") as file:
            data = file.read()

        # Opprett meldingene for forespørselen
        messages = [
            {
                "role": "system",
                "content": """
                    You are an expert in language analysis and interaction analysis in discussions, with a focus on identifying all unique speakers in dialogue.
                    Your task is to analyze the entire text provided and:

                    1. Identify and label each unique speaker based on their speech patterns, contextual cues, or dialogue markers.
                    2. Assign a unique identifier to each speaker (e.g., "Speaker 1," "Speaker 2," etc.) and determine their gender (M/F) when possible based on context.
                    3. Include all participants present in the text and ensure no speaker is omitted. Do not limit the identification to a predefined number of examples.
                    4. Look for shifts in tone, specific language usage, or structural cues in the dialogue to differentiate speakers.
                    5. Comprehensive Interaction Analysis: Evaluate and score the interactions between all debaters, not just a sample. This analysis should include every interaction and response in the provided text to ensure an accurate and holistic assessment of how each participant interacts with others.
                      Scoring Categories:
                        -Argument Strength: Rate the clarity, relevance, and persuasiveness of each participant’s arguments throughout the discussion.
                        -Engagement Style: Assess interaction qualities such as empathy, assertiveness, defensiveness, or conciliation as demonstrated across all dialogue.
                        -Tone Dynamics: Identify variations in tone such as supportive, critical, sarcastic, or enthusiastic exchanges, considering the entire range of interactions.
                        -Power Dynamics: Score power displays or imbalances, such as interruptions, speaking over others, or dismissive responses, over the entire debate.
                    6. Use an analysis model: Analyze how gender patterns may influence treatment in interactions, while controlling for other variables.
                    7. Final Scoring: Combine scores across all categories for each participant to assign a final score reflecting their overall performance and engagement style in the full debate.
                    Analyze the interactions between all participants and categorize them into gender-based combinations (M to M, F to M, F to F, M to F). Ensure the output is presented in JSON format as follows:
                    {
                        "episode_name": "<generated_name>",
                        "participants": [
                            {
                                "role": "<role>",
                                "gender": "<M/F>",
                                "background": "(party affiliation, organization, etc.)"
                            }
                        ],
                        "interaction_analysis": {
                            "M_to_M": {
                                "summary": "<summary>",
                                "score": <number>
                            },
                            "F_to_F": {
                                "summary": "<summary>",
                                "score": <number>
                            },
                            "F_to_M": {
                                "summary": "<summary>",
                                "score": <number>
                            },
                            "M_to_F": {
                                "summary": "<summary>",
                                "score": <number>
                            }
                        },
                        "overall_trends": "<description>",
                        "final_score": <number>
                    }
                """
            },
            {
                "role": "user",
                "content": f"""
                    Analyze the text below and categorize participants as “debater 1,” “debater 2,” “expert 1,” etc not their real name.
                    Evaluate how they interact with each other in all gender combinations (M to M, F to M, F to F, M to F).
                    Include all participants and do not include the moderator in the analysis.
                    In English only.

                    <data>{data}</data>

                    Response:
                """
            }
        ]

        # Forespørsel til OpenAI API
        completion = client.chat.completions.create(
        model="gpt-4o-mini",  # Replace with your actual model name
        messages=messages,
        temperature=0.5,
        response_format={"type": "json_object"},  # Guarantees that the response is in JSON format
)

        # Analyser og lagre resultatet
        if completion.choices[0].message.content:
            analysis_result = json.loads(completion.choices[0].message.content)
            analysis_result["episode_name"] = filename.replace(".vtt", "")  # Legg til episodenavn
            analysis_results.append(analysis_result)

            # Print melding når analysen er ferdig for en episode
            print(f"Finished analyzing: {filename}")

# Print den endelige JSON-variabelen som inneholder alle resultater
final_json_result = json.dumps(analysis_results, indent=4)
print(final_json_result)
# Out:
# Finished analyzing: Debatten - 8. okt. · Tidenes budsjett, men misnøyen vokser.nb-ttv.vtt
# Finished analyzing: Debatten - 17. okt. · Slik kan du spare på maten.nb-ttv.vtt
# Finished analyzing: Debatten - 24. okt. · Unge sender Ap mot sperregrensa.nb-ttv.vtt
# Finished analyzing: Debatten - Torsdag · Milliarder til norske batterier.nb-ttv.vtt
# Finished analyzing: Debatten - 22. okt. · Milliardene flyr i havvinden.nb-ttv.vtt
# Finished analyzing: Debatten - 10. okt. · Bløffebudsjett, mener opposisjonen.nb-ttv.vtt
# Finished analyzing: Debatten - 15. okt. · Skoler legges ned, bygder dør.nb-ttv.vtt
# Finished analyzing: Debatten - 3. okt. · Hvorfor bomber de hverandre？.nb-ttv.vtt
# Finished analyzing: Debatten - 29. okt. · Du blir lurt.nb-ttv.vtt
# [
#     {
#         "episode_name": "Debatten - 8. okt. \u00b7 Tidenes budsjett, men misn\u00f8yen vokser.nb-ttv",
#         "participants": [
#             {
#                 "role": "Debater 1",
#                 "gender": "M",
#                 "background": "Political editor, Swedish newspaper"
#             },
#             {
#                 "role": "Expert 1",
#                 "gender": "F",
#                 "background": "Professor, Institute of Economics, BI"
#             },
#             {
#                 "role": "Expert 2",
#                 "gender": "M",
#                 "background": "Professor of Economics, UIS"
#             },
#             {
#                 "role": "Expert 3",
#                 "gender": "M",
#                 "background": "Professor of Economic History, UiO"
#             },
#             {
#                 "role": "Expert 4",
#                 "gender": "F",
#                 "background": "Senior researcher, Folkehelseinstituttet and UiO"
#             },
#             {
#                 "role": "Expert 5",
#                 "gender": "M",
#                 "background": "Former finance minister, political party affiliation unspecified"
#             },
#             {
#                 "role": "Expert 6",
#                 "gender": "F",
#                 "background": "Former finance minister, political party affiliation unspecified"
#             }
#         ],
#         "interaction_analysis": {
#             "M_to_M": {
#                 "summary": "The male debaters engage in critical exchanges, often challenging each other's viewpoints with assertive arguments. There is a clear power dynamic with interruptions and strong rebuttals.",
#                 "score": 7
#             },
#             "F_to_F": {
#                 "summary": "The female experts engage in supportive dialogue, with a focus on collaboration and building on each other's points. There is less interruption and more conciliation.",
#                 "score": 8
#             },
#             "F_to_M": {
#                 "summary": "The female experts present their arguments clearly and assertively, often guiding the conversation and providing insights that challenge male perspectives. The interactions are generally respectful.",
#                 "score": 7
#             },
#             "M_to_F": {
#                 "summary": "The male debaters often interrupt or dominate discussions with female experts, but there are moments of acknowledgment and respect for their expertise. However, power imbalances are evident.",
#                 "score": 6
#             }
#         },
#         "overall_trends": "The debate exhibits a mix of assertive male interactions and supportive female exchanges, with a notable power dynamic where male voices often dominate despite the expertise of female participants. Gender dynamics influence the engagement style, with men more likely to interrupt and assert dominance.",
#         "final_score": 7.0
#     },
#     {
#         "episode_name": "Debatten - 17. okt. \u00b7 Slik kan du spare p\u00e5 maten.nb-ttv",
#         "participants": [
#             {
#                 "role": "Debater 1",
#                 "gender": "F",
#                 "background": "Cookbook author, food writer, and food blogger"
#             },
#             {
#                 "role": "Expert 1",
#                 "gender": "F",
#                 "background": "Senior advisor at Sifo"
#             },
#             {
#                 "role": "Expert 2",
#                 "gender": "F",
#                 "background": "Economist at Storebrand"
#             },
#             {
#                 "role": "Expert 3",
#                 "gender": "M",
#                 "background": "Frugal living expert, owner of gjerrigknark.com"
#             },
#             {
#                 "role": "Expert 4",
#                 "gender": "F",
#                 "background": "Consumer economist at Sparebank1"
#             },
#             {
#                 "role": "Debater 2",
#                 "gender": "F",
#                 "background": "Single mother and manager of a youth organization"
#             },
#             {
#                 "role": "Debater 3",
#                 "gender": "M",
#                 "background": "Retired actor and grandfather"
#             },
#             {
#                 "role": "Debater 4",
#                 "gender": "F",
#                 "background": "Student"
#             },
#             {
#                 "role": "Debater 5",
#                 "gender": "F",
#                 "background": "Influencer and savings economist"
#             },
#             {
#                 "role": "Debater 6",
#                 "gender": "M",
#                 "background": "Influencer focusing on food savings"
#             },
#             {
#                 "role": "Debater 7",
#                 "gender": "M",
#                 "background": "Influencer and food enthusiast"
#             }
#         ],
#         "interaction_analysis": {
#             "M_to_M": {
#                 "summary": "Interactions between male participants were characterized by sharing personal anecdotes and practical tips on saving money on food. They displayed camaraderie and mutual respect.",
#                 "score": 7
#             },
#             "F_to_F": {
#                 "summary": "Female participants engaged in supportive dialogues, often building on each other's suggestions and sharing personal experiences related to food budgeting and cooking.",
#                 "score": 8
#             },
#             "F_to_M": {
#                 "summary": "Interactions between female and male participants were collaborative, with females often seeking insights from males, while males provided practical advice based on their experiences.",
#                 "score": 7
#             },
#             "M_to_F": {
#                 "summary": "Male participants provided encouragement and validation to female participants, fostering a positive atmosphere for sharing ideas and tips.",
#                 "score": 8
#             }
#         },
#         "overall_trends": "The debate showcased a strong collaborative spirit among participants, with a mix of personal anecdotes and expert advice contributing to a rich discussion on food budgeting. There was a notable emphasis on practical solutions and shared experiences, highlighting gender dynamics that favored supportive interactions.",
#         "final_score": 7.5
#     },
#     {
#         "episode_name": "Debatten - 24. okt. \u00b7 Unge sender Ap mot sperregrensa.nb-ttv",
#         "participants": [
#             {
#                 "role": "Debater 1",
#                 "gender": "M",
#                 "background": "Leader of Fpu, youth wing of a political party"
#             },
#             {
#                 "role": "Debater 2",
#                 "gender": "M",
#                 "background": "Leader of AUF, youth wing of the Labour Party"
#             },
#             {
#                 "role": "Expert 1",
#                 "gender": "M",
#                 "background": "Mads Motr\u00f8en, responsible for political polling at Norstat"
#             },
#             {
#                 "role": "Expert 2",
#                 "gender": "M",
#                 "background": "Erik Friberg Ekrann, Managing Director at Ipsos"
#             }
#         ],
#         "interaction_analysis": {
#             "M_to_M": {
#                 "summary": "Debater 1 and Debater 2 engage in a back-and-forth discussion about political strategies and youth perspectives. They challenge each other's viewpoints, often interrupting and countering arguments with personal anecdotes and statistical evidence.",
#                 "score": 7
#             },
#             "F_to_F": {
#                 "summary": "No female participants are present in this debate.",
#                 "score": 0
#             },
#             "F_to_M": {
#                 "summary": "No female participants are present in this debate.",
#                 "score": 0
#             },
#             "M_to_F": {
#                 "summary": "No female participants are present in this debate.",
#                 "score": 0
#             }
#         },
#         "overall_trends": "The debate reveals a significant divide in youth political engagement, with Debater 1 emphasizing the need for change and solutions to current issues, while Debater 2 focuses on the importance of traditional values and the role of the Labour Party in addressing youth concerns. The interaction is characterized by assertiveness and a competitive tone, with both debaters trying to establish dominance in the discussion.",
#         "final_score": 7
#     },
#     {
#         "episode_name": "Debatten - Torsdag \u00b7 Milliarder til norske batterier.nb-ttv",
#         "participants": [
#             {
#                 "role": "Debater 1",
#                 "gender": "M",
#                 "background": "N\u00e6ringsminister (Ap)"
#             },
#             {
#                 "role": "Debater 2",
#                 "gender": "M",
#                 "background": "Investor"
#             },
#             {
#                 "role": "Expert 1",
#                 "gender": "F",
#                 "background": "Spr\u00e5kviter"
#             },
#             {
#                 "role": "Expert 2",
#                 "gender": "M",
#                 "background": "Batteriexpert"
#             },
#             {
#                 "role": "Expert 3",
#                 "gender": "M",
#                 "background": "Daglig leder i Morrow Batteries"
#             },
#             {
#                 "role": "Expert 4",
#                 "gender": "M",
#                 "background": "Forvalter i First-fondene"
#             },
#             {
#                 "role": "Expert 5",
#                 "gender": "F",
#                 "background": "Adm. dir. i Nysn\u00f8"
#             },
#             {
#                 "role": "Debater 3",
#                 "gender": "M",
#                 "background": "Stortingsrepresentant (H)"
#             },
#             {
#                 "role": "Debater 4",
#                 "gender": "F",
#                 "background": "N\u00e6ringsminister (Ap)"
#             },
#             {
#                 "role": "Expert 6",
#                 "gender": "M",
#                 "background": "Professor, NTNU"
#             }
#         ],
#         "interaction_analysis": {
#             "M_to_M": {
#                 "summary": "Interactions between male participants often involved assertive exchanges, with Debater 1 and Debater 2 frequently interrupting each other to assert their viewpoints. There was a competitive tone, particularly around economic viability and policy effectiveness.",
#                 "score": 7
#             },
#             "F_to_F": {
#                 "summary": "Female participants engaged in a more supportive and constructive dialogue, focusing on clarifying terms and mutual understanding. Their exchanges were less confrontational and often aimed at reaching a consensus.",
#                 "score": 8
#             },
#             "F_to_M": {
#                 "summary": "Female experts provided insights that were often met with assertive responses from male debaters. While the male participants were generally more aggressive, female experts maintained a calm demeanor, which helped de-escalate tensions.",
#                 "score": 7
#             },
#             "M_to_F": {
#                 "summary": "Male debaters frequently interrupted female participants, reflecting a power imbalance. However, female participants effectively countered with well-reasoned responses, maintaining their authority in the conversation.",
#                 "score": 6
#             }
#         },
#         "overall_trends": "The debate exhibited a clear gender dynamic, with male participants often dominating the conversation through interruptions. Female participants, while less frequently interrupting, displayed strong argumentation skills and contributed significantly to the dialogue, particularly in clarifying complex terms and advocating for clear communication.",
#         "final_score": 7
#     },
#     {
#         "episode_name": "Debatten - 22. okt. \u00b7 Milliardene flyr i havvinden.nb-ttv",
#         "participants": [
#             {
#                 "role": "Debater 1",
#                 "gender": "M",
#                 "background": "Politician, supporter of wind energy"
#             },
#             {
#                 "role": "Debater 2",
#                 "gender": "M",
#                 "background": "Director at NVE, expert on energy"
#             },
#             {
#                 "role": "Expert 1",
#                 "gender": "M",
#                 "background": "Professor at NTNU, expert on electrical energy"
#             },
#             {
#                 "role": "Expert 2",
#                 "gender": "M",
#                 "background": "Research leader at DNV, expert on sustainability"
#             },
#             {
#                 "role": "Debater 3",
#                 "gender": "M",
#                 "background": "Leader of Motvind Norge, anti-wind organization"
#             },
#             {
#                 "role": "Debater 4",
#                 "gender": "F",
#                 "background": "Director at Fornybar Norge, pro-renewable energy organization"
#             },
#             {
#                 "role": "Debater 5",
#                 "gender": "M",
#                 "background": "Editor at Europower, energy policy expert"
#             },
#             {
#                 "role": "Expert 3",
#                 "gender": "M",
#                 "background": "CEO of Deep Wind Offshore, offshore wind developer"
#             },
#             {
#                 "role": "Expert 4",
#                 "gender": "M",
#                 "background": "CEO of IKM-Gruppen, supplier company for energy sector"
#             }
#         ],
#         "interaction_analysis": {
#             "M_to_M": {
#                 "summary": "The male participants engaged in a robust exchange of ideas, often challenging one another's positions on the viability of wind energy and its economic implications. Arguments were presented with varying levels of assertiveness, with some interruptions noted.",
#                 "score": 7
#             },
#             "F_to_F": {
#                 "summary": "The interaction between the female debater and other participants was limited, but when present, it showed a supportive yet assertive tone regarding renewable energy. The female participant focused on the potential benefits of wind energy.",
#                 "score": 6
#             },
#             "F_to_M": {
#                 "summary": "The female participant engaged with male counterparts by emphasizing the need for renewable energy and addressing concerns about costs. The tone was collaborative, though at times she had to assert her points against stronger male voices.",
#                 "score": 7
#             },
#             "M_to_F": {
#                 "summary": "Male participants often addressed the female participant with a mix of respect and challenge. There were moments of defensiveness from males when her points contradicted their views, indicating a slight power imbalance.",
#                 "score": 5
#             }
#         },
#         "overall_trends": "The debate exhibited a mix of assertive and collaborative interactions, with male participants dominating the discussion. Female representation was present but often had to navigate a challenging environment. Gender dynamics showed some power imbalances, particularly in how ideas were received and debated.",
#         "final_score": 6.25
#     },
#     {
#         "episode_name": "Debatten - 10. okt. \u00b7 Bl\u00f8ffebudsjett, mener opposisjonen.nb-ttv",
#         "participants": [
#             {
#                 "role": "Debater 1",
#                 "gender": "M",
#                 "background": "Leader of the Labour Party (Ap)"
#             },
#             {
#                 "role": "Debater 2",
#                 "gender": "F",
#                 "background": "Leader of the Conservative Party (H\u00f8yre)"
#             },
#             {
#                 "role": "Debater 3",
#                 "gender": "F",
#                 "background": "Leader of the Socialist Left Party (SV)"
#             },
#             {
#                 "role": "Debater 4",
#                 "gender": "M",
#                 "background": "Leader of the Progress Party (Frp)"
#             },
#             {
#                 "role": "Debater 5",
#                 "gender": "F",
#                 "background": "Leader of the Centre Party (Sp)"
#             },
#             {
#                 "role": "Debater 6",
#                 "gender": "F",
#                 "background": "Leader of the Christian Democratic Party (KrF)"
#             },
#             {
#                 "role": "Debater 7",
#                 "gender": "M",
#                 "background": "Leader of the Red Party (R\u00f8dt)"
#             }
#         ],
#         "interaction_analysis": {
#             "M_to_M": {
#                 "summary": "Debater 1 and Debater 4 exchanged strong arguments regarding economic policies and social welfare, often interrupting each other to assert their points.",
#                 "score": 7
#             },
#             "F_to_F": {
#                 "summary": "Debater 2 and Debater 3 had a constructive exchange focused on social issues and environmental policies, showing respect for each other's viewpoints.",
#                 "score": 8
#             },
#             "F_to_M": {
#                 "summary": "Debater 2 and Debater 1 had a dynamic interaction where Debater 2 challenged Debater 1's economic policies, leading to a heated but respectful discussion.",
#                 "score": 7
#             },
#             "M_to_F": {
#                 "summary": "Debater 4 frequently interrupted Debater 5, creating a somewhat defensive atmosphere, while Debater 5 maintained composure and countered effectively.",
#                 "score": 6
#             }
#         },
#         "overall_trends": "The debate showcased a mix of assertiveness and cooperation among participants, with noticeable power dynamics influencing the interactions. Female debaters tended to engage more collaboratively, while male debaters exhibited more competitive behaviors.",
#         "final_score": 7
#     },
#     {
#         "episode_name": "Debatten - 15. okt. \u00b7 Skoler legges ned, bygder d\u00f8r.nb-ttv",
#         "participants": [
#             {
#                 "role": "Debater 1",
#                 "gender": "M",
#                 "background": "Finansminister and leader of Sp"
#             },
#             {
#                 "role": "Debater 2",
#                 "gender": "M",
#                 "background": "Fylkesordf\u00f8rer in Innlandet, Ap"
#             },
#             {
#                 "role": "Debater 3",
#                 "gender": "F",
#                 "background": "Researcher from Bergen"
#             },
#             {
#                 "role": "Debater 4",
#                 "gender": "M",
#                 "background": "Kokk and entrepreneur from Tessand"
#             },
#             {
#                 "role": "Debater 5",
#                 "gender": "F",
#                 "background": "Helsesista"
#             },
#             {
#                 "role": "Debater 6",
#                 "gender": "M",
#                 "background": "Ordf\u00f8rer in Lindesnes from Frp"
#             },
#             {
#                 "role": "Debater 7",
#                 "gender": "F",
#                 "background": "Kunnskapsminister from Ap"
#             },
#             {
#                 "role": "Debater 8",
#                 "gender": "F",
#                 "background": "Commentator in Aftenposten"
#             },
#             {
#                 "role": "Debater 9",
#                 "gender": "M",
#                 "background": "Stortingsrepresentant from H\u00f8yre"
#             },
#             {
#                 "role": "Debater 10",
#                 "gender": "M",
#                 "background": "Sjefredakt\u00f8r in Tr\u00f8nderavisa"
#             },
#             {
#                 "role": "Youth Speaker 1",
#                 "gender": "F",
#                 "background": "15-year-old student"
#             },
#             {
#                 "role": "Youth Speaker 2",
#                 "gender": "F",
#                 "background": "18-year-old student"
#             },
#             {
#                 "role": "Youth Speaker 3",
#                 "gender": "M",
#                 "background": "Second-year student"
#             }
#         ],
#         "interaction_analysis": {
#             "M_to_M": {
#                 "summary": "Debaters engaged in a heated exchange, often interrupting each other with counterarguments.",
#                 "score": 4
#             },
#             "F_to_F": {
#                 "summary": "Female debaters showed support for each other's points, often reinforcing arguments about the impact on youth.",
#                 "score": 5
#             },
#             "F_to_M": {
#                 "summary": "Female debaters challenged male counterparts assertively, emphasizing the consequences of their policies.",
#                 "score": 4
#             },
#             "M_to_F": {
#                 "summary": "Male debaters often dismissed or minimized female perspectives, leading to a power imbalance.",
#                 "score": 3
#             }
#         },
#         "overall_trends": "The debate highlighted significant gender dynamics, with female speakers often facing interruptions and dismissal from male counterparts. However, they maintained a strong presence and solidarity among themselves.",
#         "final_score": 4.0
#     },
#     {
#         "episode_name": "Debatten - 3. okt. \u00b7 Hvorfor bomber de hverandre\uff1f.nb-ttv",
#         "participants": [
#             {
#                 "role": "debater 1",
#                 "gender": "F",
#                 "background": "Conflict and International Law Researcher"
#             },
#             {
#                 "role": "debater 2",
#                 "gender": "M",
#                 "background": "Former Ambassador to Israel, USA, and Afghanistan"
#             },
#             {
#                 "role": "debater 3",
#                 "gender": "M",
#                 "background": "Professor Emeritus in Middle Eastern Studies"
#             },
#             {
#                 "role": "debater 4",
#                 "gender": "F",
#                 "background": "Researcher at the Defence University College"
#             },
#             {
#                 "role": "debater 5",
#                 "gender": "M",
#                 "background": "Senior Economist at Aker BP"
#             },
#             {
#                 "role": "debater 6",
#                 "gender": "M",
#                 "background": "Chief Researcher at the Defence Research Institute"
#             }
#         ],
#         "interaction_analysis": {
#             "M_to_M": {
#                 "summary": "Debater 2 and Debater 3 engaged in a back-and-forth discussion about the historical context of the conflict, often agreeing but also challenging each other's points.",
#                 "score": 7
#             },
#             "F_to_F": {
#                 "summary": "Debater 1 and Debater 4 shared insights on the motivations of Iran and its relationship with regional actors, demonstrating a collaborative engagement.",
#                 "score": 8
#             },
#             "F_to_M": {
#                 "summary": "Debater 1 often posed critical questions to Debater 2 and Debater 3, challenging their views on the implications of Israeli actions, which led to a dynamic exchange.",
#                 "score": 9
#             },
#             "M_to_F": {
#                 "summary": "Debater 2 and Debater 3 were receptive to Debater 4's insights on military strategies, showing respect for her expertise while providing their perspectives.",
#                 "score": 6
#             }
#         },
#         "overall_trends": "The discussion highlighted a collaborative yet critical atmosphere, with both male and female participants engaging substantively. Female debaters displayed assertiveness in questioning male counterparts, while male debaters showed a tendency to build on each other's arguments.",
#         "final_score": 8
#     },
#     {
#         "episode_name": "Debatten - 29. okt. \u00b7 Du blir lurt.nb-ttv",
#         "participants": [
#             {
#                 "role": "Debater 1",
#                 "gender": "F",
#                 "background": "Medical student at UiO"
#             },
#             {
#                 "role": "Expert 1",
#                 "gender": "M",
#                 "background": "Director at National Communications Authority (Nkom)"
#             },
#             {
#                 "role": "Expert 2",
#                 "gender": "M",
#                 "background": "Director at Telenor Norway"
#             },
#             {
#                 "role": "Debater 2",
#                 "gender": "M",
#                 "background": "Parent-Teacher Association member"
#             },
#             {
#                 "role": "Expert 3",
#                 "gender": "F",
#                 "background": "Director of Economic Crime at Sparebank 1"
#             },
#             {
#                 "role": "Expert 4",
#                 "gender": "M",
#                 "background": "Leader of Financial Cyber Crime Center at DNB"
#             },
#             {
#                 "role": "Debater 3",
#                 "gender": "F",
#                 "background": "Victim of home visit fraud"
#             },
#             {
#                 "role": "Expert 5",
#                 "gender": "M",
#                 "background": "Security manager at Vadla Trygghetsbyr\u00e5 AS"
#             },
#             {
#                 "role": "Debater 4",
#                 "gender": "M",
#                 "background": "Ethical hacker"
#             }
#         ],
#         "interaction_analysis": {
#             "M_to_M": {
#                 "summary": "The interactions between male speakers often involved assertive questioning and rebuttals, showcasing a competitive tone. They tended to build on each other's points while also challenging assumptions.",
#                 "score": 7
#             },
#             "F_to_F": {
#                 "summary": "Female speakers engaged in empathetic exchanges, often discussing personal experiences related to fraud. Their tone was supportive and informative, fostering a sense of community.",
#                 "score": 8
#             },
#             "F_to_M": {
#                 "summary": "Interactions between female and male speakers were generally respectful, with females presenting personal narratives that were acknowledged by male experts. Males tended to provide factual responses or solutions.",
#                 "score": 7
#             },
#             "M_to_F": {
#                 "summary": "Male speakers often took a more dominant role in discussions with female participants, occasionally interrupting or redirecting the conversation. However, this was balanced by moments of acknowledgment of female experiences.",
#                 "score": 6
#             }
#         },
#         "overall_trends": "The discussion highlighted a mix of assertiveness and empathy, with male participants often leading the debate while females contributed personal stories that enriched the conversation. There were noticeable gender dynamics, with males dominating in terms of speaking time and authority, while females provided valuable insights and emotional context.",
#         "final_score": 7.5
#     }
# ]

# %% [markdown]
# ##Make to DF

# %%
import pandas as pd

# Convert the JSON results into DataFrames
scores_data = []
participants_data = []

for result in analysis_results:
    episode_name = result["episode_name"]

    # Add score data
    for interaction, details in result["interaction_analysis"].items():
        scores_data.append({
            "episode_name": episode_name,
            "interaction_type": interaction,
            "summary": details["summary"],
            "score": details["score"]
        })

    # Add participant data
    for participant in result["participants"]:
        participants_data.append({
            "episode_name": episode_name,
            "role": participant["role"],
            "gender": participant["gender"],
            "background": participant["background"]
        })

# Create DataFrames
scores_df = pd.DataFrame(scores_data)
participants_df = pd.DataFrame(participants_data)
# Display DataFrames using pandas display method
print("Scores DataFrame:")
display(scores_df)

print("\nParticipants DataFrame:")
display(participants_df)
# Out:
# Scores DataFrame:
#                                          episode_name interaction_type  \
# 0   Debatten - 8. okt. · Tidenes budsjett, men mis...           M_to_M
# 1   Debatten - 8. okt. · Tidenes budsjett, men mis...           F_to_F
# 2   Debatten - 8. okt. · Tidenes budsjett, men mis...           F_to_M
# 3   Debatten - 8. okt. · Tidenes budsjett, men mis...           M_to_F
# 4   Debatten - 17. okt. · Slik kan du spare på mat...           M_to_M
# 5   Debatten - 17. okt. · Slik kan du spare på mat...           F_to_F
# 6   Debatten - 17. okt. · Slik kan du spare på mat...           F_to_M
# 7   Debatten - 17. okt. · Slik kan du spare på mat...           M_to_F
# 8   Debatten - 24. okt. · Unge sender Ap mot sperr...           M_to_M
# 9   Debatten - 24. okt. · Unge sender Ap mot sperr...           F_to_F
# 10  Debatten - 24. okt. · Unge sender Ap mot sperr...           F_to_M
# 11  Debatten - 24. okt. · Unge sender Ap mot sperr...           M_to_F
# 12  Debatten - Torsdag · Milliarder til norske bat...           M_to_M
# 13  Debatten - Torsdag · Milliarder til norske bat...           F_to_F
# 14  Debatten - Torsdag · Milliarder til norske bat...           F_to_M
# 15  Debatten - Torsdag · Milliarder til norske bat...           M_to_F
# 16  Debatten - 22. okt. · Milliardene flyr i havvi...           M_to_M
# 17  Debatten - 22. okt. · Milliardene flyr i havvi...           F_to_F
# 18  Debatten - 22. okt. · Milliardene flyr i havvi...           F_to_M
# 19  Debatten - 22. okt. · Milliardene flyr i havvi...           M_to_F
# 20  Debatten - 10. okt. · Bløffebudsjett, mener op...           M_to_M
# 21  Debatten - 10. okt. · Bløffebudsjett, mener op...           F_to_F
# 22  Debatten - 10. okt. · Bløffebudsjett, mener op...           F_to_M
# 23  Debatten - 10. okt. · Bløffebudsjett, mener op...           M_to_F
# 24  Debatten - 15. okt. · Skoler legges ned, bygde...           M_to_M
# 25  Debatten - 15. okt. · Skoler legges ned, bygde...           F_to_F
# 26  Debatten - 15. okt. · Skoler legges ned, bygde...           F_to_M
# 27  Debatten - 15. okt. · Skoler legges ned, bygde...           M_to_F
# 28  Debatten - 3. okt. · Hvorfor bomber de hverand...           M_to_M
# 29  Debatten - 3. okt. · Hvorfor bomber de hverand...           F_to_F
# 30  Debatten - 3. okt. · Hvorfor bomber de hverand...           F_to_M
# 31  Debatten - 3. okt. · Hvorfor bomber de hverand...           M_to_F
# 32          Debatten - 29. okt. · Du blir lurt.nb-ttv           M_to_M
# 33          Debatten - 29. okt. · Du blir lurt.nb-ttv           F_to_F
# 34          Debatten - 29. okt. · Du blir lurt.nb-ttv           F_to_M
# 35          Debatten - 29. okt. · Du blir lurt.nb-ttv           M_to_F
#
#                                               summary  score
# 0   The male debaters engage in critical exchanges...      7
# 1   The female experts engage in supportive dialog...      8
# 2   The female experts present their arguments cle...      7
# 3   The male debaters often interrupt or dominate ...      6
# 4   Interactions between male participants were ch...      7
# 5   Female participants engaged in supportive dial...      8
# 6   Interactions between female and male participa...      7
# 7   Male participants provided encouragement and v...      8
# 8   Debater 1 and Debater 2 engage in a back-and-f...      7
# 9   No female participants are present in this deb...      0
# 10  No female participants are present in this deb...      0
# 11  No female participants are present in this deb...      0
# 12  Interactions between male participants often i...      7
# 13  Female participants engaged in a more supporti...      8
# 14  Female experts provided insights that were oft...      7
# 15  Male debaters frequently interrupted female pa...      6
# 16  The male participants engaged in a robust exch...      7
# 17  The interaction between the female debater and...      6
# 18  The female participant engaged with male count...      7
# 19  Male participants often addressed the female p...      5
# 20  Debater 1 and Debater 4 exchanged strong argum...      7
# 21  Debater 2 and Debater 3 had a constructive exc...      8
# 22  Debater 2 and Debater 1 had a dynamic interact...      7
# 23  Debater 4 frequently interrupted Debater 5, cr...      6
# 24  Debaters engaged in a heated exchange, often i...      4
# 25  Female debaters showed support for each other'...      5
# 26  Female debaters challenged male counterparts a...      4
# 27  Male debaters often dismissed or minimized fem...      3
# 28  Debater 2 and Debater 3 engaged in a back-and-...      7
# 29  Debater 1 and Debater 4 shared insights on the...      8
# 30  Debater 1 often posed critical questions to De...      9
# 31  Debater 2 and Debater 3 were receptive to Deba...      6
# 32  The interactions between male speakers often i...      7
# 33  Female speakers engaged in empathetic exchange...      8
# 34  Interactions between female and male speakers ...      7
# 35  Male speakers often took a more dominant role ...      6
# Participants DataFrame:
#                                          episode_name       role gender  \
# 0   Debatten - 8. okt. · Tidenes budsjett, men mis...  Debater 1      M
# 1   Debatten - 8. okt. · Tidenes budsjett, men mis...   Expert 1      F
# 2   Debatten - 8. okt. · Tidenes budsjett, men mis...   Expert 2      M
# 3   Debatten - 8. okt. · Tidenes budsjett, men mis...   Expert 3      M
# 4   Debatten - 8. okt. · Tidenes budsjett, men mis...   Expert 4      F
# ..                                                ...        ...    ...
# 71          Debatten - 29. okt. · Du blir lurt.nb-ttv   Expert 3      F
# 72          Debatten - 29. okt. · Du blir lurt.nb-ttv   Expert 4      M
# 73          Debatten - 29. okt. · Du blir lurt.nb-ttv  Debater 3      F
# 74          Debatten - 29. okt. · Du blir lurt.nb-ttv   Expert 5      M
# 75          Debatten - 29. okt. · Du blir lurt.nb-ttv  Debater 4      M
#
#                                           background
# 0                Political editor, Swedish newspaper
# 1              Professor, Institute of Economics, BI
# 2                        Professor of Economics, UIS
# 3                 Professor of Economic History, UiO
# 4   Senior researcher, Folkehelseinstituttet and UiO
# ..                                               ...
# 71         Director of Economic Crime at Sparebank 1
# 72     Leader of Financial Cyber Crime Center at DNB
# 73                        Victim of home visit fraud
# 74        Security manager at Vadla Trygghetsbyrå AS
# 75                                    Ethical hacker
#
# [76 rows x 4 columns]

# %% [markdown]
# ##Save as xlsx

# %%
# Save the DataFrames as separate Excel files in /content/ directory
scores_output_path = '/content/scores_analysis_results.xlsx'
participants_output_path = '/content/participants_analysis_results.xlsx'

# Save each DataFrame to an Excel file
scores_df.to_excel(scores_output_path, index=False)
participants_df.to_excel(participants_output_path, index=False)

(scores_output_path, participants_output_path)
# Out:
# ('/content/scores_analysis_results.xlsx',
#  '/content/participants_analysis_results.xlsx')
